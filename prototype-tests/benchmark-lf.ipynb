# %%
import networkx as nx
import networkx.algorithms.community as nx_comm
from networkx.generators.community import LFR_benchmark_graph
from networkx.algorithms import bipartite
import numpy as np
import scipy as sp
from scipy.sparse import coo_array
from scipy import sparse
from cdlib import algorithms
from cdlib import evaluation
import sklearn
from utils import *
from distances import *
from consensus import *
import math
import itertools
import random
import time
from pathlib import Path
# Out:
# 			<script type="text/javascript">
# 			<!--
#
# 			{
# 				var element = document.getElementById('NetworKit_script');
# 				if (element) {
# 					element.parentNode.removeChild(element);
# 				}
# 				element = document.createElement('script');
# 				element.type = 'text/javascript';
# 				element.innerHTML = 'function NetworKit_pageEmbed(id) { var i, j; var elements; elements = document.getElementById(id).getElementsByClassName("Plot"); for (i=0; i<elements.length; i++) { elements[i].id = id + "_Plot_" + i; var data = elements[i].getAttribute("data-image").split("|"); elements[i].removeAttribute("data-image"); var content = "<div class=\\"Image\\" id=\\"" + elements[i].id + "_Image\\" />"; elements[i].innerHTML = content; elements[i].setAttribute("data-image-index", 0); elements[i].setAttribute("data-image-length", data.length); for (j=0; j<data.length; j++) { elements[i].setAttribute("data-image-" + j, data[j]); } NetworKit_plotUpdate(elements[i]); elements[i].onclick = function (e) { NetworKit_overlayShow((e.target) ? e.target : e.srcElement); } } elements = document.getElementById(id).getElementsByClassName("HeatCell"); for (i=0; i<elements.length; i++) { var data = parseFloat(elements[i].getAttribute("data-heat")); var color = "#00FF00"; if (data <= 1 && data > 0) { color = "hsla(0, 100%, 75%, " + (data) + ")"; } else if (data <= 0 && data >= -1) { color = "hsla(240, 100%, 75%, " + (-data) + ")"; } elements[i].style.backgroundColor = color; } elements = document.getElementById(id).getElementsByClassName("Details"); for (i=0; i<elements.length; i++) { elements[i].setAttribute("data-title", "-"); NetworKit_toggleDetails(elements[i]); elements[i].onclick = function (e) { NetworKit_toggleDetails((e.target) ? e.target : e.srcElement); } } elements = document.getElementById(id).getElementsByClassName("MathValue"); for (i=elements.length-1; i>=0; i--) { value = elements[i].innerHTML.trim(); if (value === "nan") { elements[i].parentNode.innerHTML = "" } } elements = document.getElementById(id).getElementsByClassName("SubCategory"); for (i=elements.length-1; i>=0; i--) { value = elements[i].innerHTML.trim(); if (value === "") { elements[i].parentNode.removeChild(elements[i]) } } elements = document.getElementById(id).getElementsByClassName("Category"); for (i=elements.length-1; i>=0; i--) { value = elements[i].innerHTML.trim(); if (value === "") { elements[i].parentNode.removeChild(elements[i]) } } var isFirefox = false; try { isFirefox = typeof InstallTrigger !== "undefined"; } catch (e) {} if (!isFirefox) { alert("Currently the function\'s output is only fully supported by Firefox."); } } function NetworKit_plotUpdate(source) { var index = source.getAttribute("data-image-index"); var data = source.getAttribute("data-image-" + index); var image = document.getElementById(source.id + "_Image"); image.style.backgroundImage = "url(" + data + ")"; } function NetworKit_showElement(id, show) { var element = document.getElementById(id); element.style.display = (show) ? "block" : "none"; } function NetworKit_overlayShow(source) { NetworKit_overlayUpdate(source); NetworKit_showElement("NetworKit_Overlay", true); } function NetworKit_overlayUpdate(source) { document.getElementById("NetworKit_Overlay_Title").innerHTML = source.title; var index = source.getAttribute("data-image-index"); var data = source.getAttribute("data-image-" + index); var image = document.getElementById("NetworKit_Overlay_Image"); image.setAttribute("data-id", source.id); image.style.backgroundImage = "url(" + data + ")"; var link = document.getElementById("NetworKit_Overlay_Toolbar_Bottom_Save"); link.href = data; link.download = source.title + ".svg"; } function NetworKit_overlayImageShift(delta) { var image = document.getElementById("NetworKit_Overlay_Image"); var source = document.getElementById(image.getAttribute("data-id")); var index = parseInt(source.getAttribute("data-image-index")); var length = parseInt(source.getAttribute("data-image-length")); var index = (index+delta) % length; if (index < 0) { index = length + index; } source.setAttribute("data-image-index", index); NetworKit_overlayUpdate(source); } function NetworKit_toggleDetails(source) { var childs = source.children; var show = false; if (source.getAttribute("data-title") == "-") { ...
# 				element.setAttribute('id', 'NetworKit_script');
# 				document.head.appendChild(element);
# 			}
#
#
# 			{
# 				var element = document.getElementById('NetworKit_style');
# 				if (element) {
# 					element.parentNode.removeChild(element);
# 				}
# 				element = document.createElement('style');
# 				element.type = 'text/css';
# 				element.innerHTML = '.NetworKit_Page { font-family: Arial, Helvetica, sans-serif; font-size: 14px; } .NetworKit_Page .Value:before { font-family: Arial, Helvetica, sans-serif; font-size: 1.05em; content: attr(data-title) ":"; margin-left: -2.5em; padding-right: 0.5em; } .NetworKit_Page .Details .Value:before { display: block; } .NetworKit_Page .Value { font-family: monospace; white-space: pre; padding-left: 2.5em; white-space: -moz-pre-wrap !important; white-space: -pre-wrap; white-space: -o-pre-wrap; white-space: pre-wrap; word-wrap: break-word; tab-size: 4; -moz-tab-size: 4; } .NetworKit_Page .Category { clear: both; padding-left: 1em; margin-bottom: 1.5em; } .NetworKit_Page .Category:before { content: attr(data-title); font-size: 1.75em; display: block; margin-left: -0.8em; margin-bottom: 0.5em; } .NetworKit_Page .SubCategory { margin-bottom: 1.5em; padding-left: 1em; } .NetworKit_Page .SubCategory:before { font-size: 1.6em; display: block; margin-left: -0.8em; margin-bottom: 0.5em; } .NetworKit_Page .SubCategory[data-title]:before { content: attr(data-title); } .NetworKit_Page .Block { display: block; } .NetworKit_Page .Block:after { content: "."; visibility: hidden; display: block; height: 0; clear: both; } .NetworKit_Page .Block .Thumbnail_Overview, .NetworKit_Page .Block .Thumbnail_ScatterPlot { width: 260px; float: left; } .NetworKit_Page .Block .Thumbnail_Overview img, .NetworKit_Page .Block .Thumbnail_ScatterPlot img { width: 260px; } .NetworKit_Page .Block .Thumbnail_Overview:before, .NetworKit_Page .Block .Thumbnail_ScatterPlot:before { display: block; text-align: center; font-weight: bold; } .NetworKit_Page .Block .Thumbnail_Overview:before { content: attr(data-title); } .NetworKit_Page .HeatCell { font-family: "Courier New", Courier, monospace; cursor: pointer; } .NetworKit_Page .HeatCell, .NetworKit_Page .HeatCellName { display: inline; padding: 0.1em; margin-right: 2px; background-color: #FFFFFF } .NetworKit_Page .HeatCellName { margin-left: 0.25em; } .NetworKit_Page .HeatCell:before { content: attr(data-heat); display: inline-block; color: #000000; width: 4em; text-align: center; } .NetworKit_Page .Measure { clear: both; } .NetworKit_Page .Measure .Details { cursor: pointer; } .NetworKit_Page .Measure .Details:before { content: "[" attr(data-title) "]"; display: block; } .NetworKit_Page .Measure .Details .Value { border-left: 1px dotted black; margin-left: 0.4em; padding-left: 3.5em; pointer-events: none; } .NetworKit_Page .Measure .Details .Spacer:before { content: "."; opacity: 0.0; pointer-events: none; } .NetworKit_Page .Measure .Plot { width: 440px; height: 440px; cursor: pointer; float: left; margin-left: -0.9em; margin-right: 20px; } .NetworKit_Page .Measure .Plot .Image { background-repeat: no-repeat; background-position: center center; background-size: contain; height: 100%; pointer-events: none; } .NetworKit_Page .Measure .Stat { width: 500px; float: left; } .NetworKit_Page .Measure .Stat .Group { padding-left: 1.25em; margin-bottom: 0.75em; } .NetworKit_Page .Measure .Stat .Group .Title { font-size: 1.1em; display: block; margin-bottom: 0.3em; margin-left: -0.75em;
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'ASLPAw'}

# %%
cons_name = "lf"

# %%
def prep_consensus_graph(P_list):
    G = nx.Graph(P_list[0]["graph"])
    n = len(list(G.nodes()))
    k = len(P_list)
    #print("Number of nodes", n)
    
    row = []
    col = []
    val = []
    for x in P_list:
        graph = x["graph"]
        partition = x["partition"]
        for cluster in partition:
            for i in range(len(cluster)):
                for j in range(i+1, len(cluster)):
                    item_1 = cluster[i]
                    item_2 = cluster[j]
                    row.append(int(item_1))
                    col.append(int(item_2))
                    val.append(int(1))
                    
    r = coo_array((val, (row, col)), shape=(n, n))
    rDense = r.toarray()
    threshold = k / 2
    rDense[np.abs(rDense) < threshold] = 0
    
    G = nx.from_numpy_array(rDense)
    return G

# %% [markdown]
# # n=200

# %%
n = 200
expected_clusters = []
for i in range(4):
    expected_clusters.append(random.randint(int(n ** (1. / 3)),3*int(n ** (1. / 2))))
    
alg_params = {
    "label_propagation": None,
    "leiden": None,
    "significance_communities": None,
    "surprise_communities": None,
    "greedy_modularity": None,
    "paris": None,
    "louvain": {
        "resolution": [0.75, 1.0, 1.25, 1.5],
        "randomize": [314159, 2718]
    },
    "infomap": None,
    "walktrap": None,
    "markov_clustering": {
        "inflation": [1.2, 1.5, 2, 2.5],
        "pruning_threshold": [0.01, 0.001],
        "convergence_check_frequency": [100]
    },
    "em": {
        "k": list(expected_clusters)
    },
    "sbm_dl": None,
    "spinglass": {
        "spins": list(expected_clusters)
    },
    "ricci_community": {
        "alpha": [0.3, 0.5, 0.6, 0.75]
    }
}

clustering_enumeration = []
count = 0
for alg, params in alg_params.items():
    param_combinations = []
    param_names = []
    if params is not None:
        iterables = []
        param_names = []
        for param in params.keys():
            iterables.append(list(params[param]))
            param_names.append(param)
        param_combinations = list(itertools.product(*iterables))
    if len(param_combinations) > 0:
        for param_combination in param_combinations:
            expr = "algorithms."+alg+"(G"
            for i in range(len(param_names)):
                expr = expr + "," + param_names[i] + "=" + str(param_combination[i])
            expr = expr + ")"
            clustering_enumeration.append((expr,count))
            count = count + 1      
    else:
        expr = "algorithms."+alg+"(G)"
        clustering_enumeration.append((expr,count))
        count = count + 1
        
print(clustering_enumeration)
# Out:
# [('algorithms.label_propagation(G)', 0), ('algorithms.leiden(G)', 1), ('algorithms.significance_communities(G)', 2), ('algorithms.surprise_communities(G)', 3), ('algorithms.greedy_modularity(G)', 4), ('algorithms.paris(G)', 5), ('algorithms.louvain(G,resolution=0.75,randomize=314159)', 6), ('algorithms.louvain(G,resolution=0.75,randomize=2718)', 7), ('algorithms.louvain(G,resolution=1.0,randomize=314159)', 8), ('algorithms.louvain(G,resolution=1.0,randomize=2718)', 9), ('algorithms.louvain(G,resolution=1.25,randomize=314159)', 10), ('algorithms.louvain(G,resolution=1.25,randomize=2718)', 11), ('algorithms.louvain(G,resolution=1.5,randomize=314159)', 12), ('algorithms.louvain(G,resolution=1.5,randomize=2718)', 13), ('algorithms.infomap(G)', 14), ('algorithms.walktrap(G)', 15), ('algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.01,convergence_check_frequency=100)', 16), ('algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.001,convergence_check_frequency=100)', 17), ('algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.01,convergence_check_frequency=100)', 18), ('algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.001,convergence_check_frequency=100)', 19), ('algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.01,convergence_check_frequency=100)', 20), ('algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.001,convergence_check_frequency=100)', 21), ('algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.01,convergence_check_frequency=100)', 22), ('algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.001,convergence_check_frequency=100)', 23), ('algorithms.em(G,k=23)', 24), ('algorithms.em(G,k=6)', 25), ('algorithms.em(G,k=28)', 26), ('algorithms.em(G,k=21)', 27), ('algorithms.sbm_dl(G)', 28), ('algorithms.spinglass(G,spins=23)', 29), ('algorithms.spinglass(G,spins=6)', 30), ('algorithms.spinglass(G,spins=28)', 31), ('algorithms.spinglass(G,spins=21)', 32), ('algorithms.ricci_community(G,alpha=0.3)', 33), ('algorithms.ricci_community(G,alpha=0.5)', 34), ('algorithms.ricci_community(G,alpha=0.6)', 35), ('algorithms.ricci_community(G,alpha=0.75)', 36)]

# %%
import random

n = 200
fileprefix = "LFR/" + "n" + str(n) + "/"
mus = [1, 2, 3, 4]
#mus = [4]
gammas = [30]
betas = [11]
for mu in mus:
    for gamma in gammas:
        for beta in betas:
            P_list = []
            fname = "LFR_n" + str(n) + "_mu0" + str(mu) + "_gamma" + str(gamma) + "_beta" + str(beta)
            graph_file = fileprefix + fname + ".mtx"
            print(graph_file)
            G = None
            with open(graph_file) as f:
                G = nx.from_scipy_sparse_array(spio.mmread(f), create_using=nx.Graph)
                coms = None
                new_adj_mat = nx.to_numpy_array(G)
                old_adj_mat = np.zeros(new_adj_mat.shape)
                diff_mat = old_adj_mat - new_adj_mat
                old_adj_mat = np.array(new_adj_mat)
                norm = np.linalg.norm(diff_mat)
                P_star = None
                for it in range(20):
                    P_list = []
                    if it > 0:
                        for k in clustering_enumeration:
                            try:
                                coms = eval(k[0])
                                print("mu:", mu, "it:", it, k[0], len(coms.communities))
                                P_list.append({"graph": nx.Graph(G), "partition": list(coms.communities)})
                                #stats.append({"mu": mu, "it": it, "norm": norm, "alg": k[0], "ncluster": len(coms.communities)})
                                count = count + 1
                            except:
                                print("UNSUCCESSFUL", k[0])
                    else:
                        for k in clustering_enumeration:
                            clust_file = fileprefix + fname + "." + str(k[1])
                            if Path(clust_file).is_file():
                                partition = read_clust_lst(clust_file)
                                print("mu:", mu, "it:", it, k[0], len(partition))
                                P_list.append({"graph": nx.Graph(G), "partition": list(partition)})
                                #stats.append({"mu": mu, "it": it, "norm": norm, "alg": k[0], "ncluster": len(partition)})
                    G = prep_consensus_graph(P_list)
                    
                    new_adj_mat = nx.to_numpy_array(G)
                    diff_mat = old_adj_mat - new_adj_mat
                    norm = np.linalg.norm(diff_mat)
                    old_adj_mat = np.array(new_adj_mat)
                    #stats.append({"mu": mu, "it": it, "norm": norm, "alg": "lf-louvain", "ncluster": len(P_star["partition"])})
                    print("mu:", mu, "it:", it, "norm:", norm)
                    P_star = P_list[0]
                    if norm < 1e-3:
                        print("Converged")
                        print("---")
                        break
                    print("---")
                        
                write_clust_lst(P_star["partition"], fileprefix + fname + "." + cons_name)
        
#df = pd.DataFrame(stats)
#df.to_csv("benchmark-lf-convergence-multi-alg.csv", index=False)
# Out:
# LFR/n200/LFR_n200_mu01_gamma30_beta11.mtx
# mu: 1 it: 0 algorithms.label_propagation(G) 20
# mu: 1 it: 0 algorithms.leiden(G) 12
# mu: 1 it: 0 algorithms.significance_communities(G) 26
# mu: 1 it: 0 algorithms.surprise_communities(G) 199
# mu: 1 it: 0 algorithms.greedy_modularity(G) 10
# mu: 1 it: 0 algorithms.paris(G) 15
# mu: 1 it: 0 algorithms.louvain(G,resolution=0.75,randomize=314159) 12
# mu: 1 it: 0 algorithms.louvain(G,resolution=0.75,randomize=2718) 12
# mu: 1 it: 0 algorithms.louvain(G,resolution=1.0,randomize=314159) 12
# mu: 1 it: 0 algorithms.louvain(G,resolution=1.0,randomize=2718) 12
# mu: 1 it: 0 algorithms.louvain(G,resolution=1.25,randomize=314159) 14
# mu: 1 it: 0 algorithms.louvain(G,resolution=1.25,randomize=2718) 14
# mu: 1 it: 0 algorithms.louvain(G,resolution=1.5,randomize=314159) 14
# mu: 1 it: 0 algorithms.louvain(G,resolution=1.5,randomize=2718) 14
# mu: 1 it: 0 algorithms.infomap(G) 16
# mu: 1 it: 0 algorithms.walktrap(G) 15
# mu: 1 it: 0 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.01,convergence_check_frequency=100) 12
# mu: 1 it: 0 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.001,convergence_check_frequency=100) 1
# mu: 1 it: 0 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.01,convergence_check_frequency=100) 16
# mu: 1 it: 0 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 0 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.01,convergence_check_frequency=100) 19
# mu: 1 it: 0 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.001,convergence_check_frequency=100) 19
# mu: 1 it: 0 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.01,convergence_check_frequency=100) 31
# mu: 1 it: 0 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.001,convergence_check_frequency=100) 31
# mu: 1 it: 0 algorithms.em(G,k=11) 12
# mu: 1 it: 0 algorithms.em(G,k=41) 9
# mu: 1 it: 0 algorithms.em(G,k=40) 16
# mu: 1 it: 0 algorithms.em(G,k=12) 8
# mu: 1 it: 0 algorithms.sbm_dl(G) 13
# mu: 1 it: 0 algorithms.spinglass(G,spins=11) 14
# mu: 1 it: 0 algorithms.spinglass(G,spins=41) 12
# mu: 1 it: 0 algorithms.spinglass(G,spins=40) 15
# mu: 1 it: 0 algorithms.spinglass(G,spins=12) 12
# mu: 1 it: 0 algorithms.ricci_community(G,alpha=0.3) 14
# mu: 1 it: 0 algorithms.ricci_community(G,alpha=0.5) 15
# mu: 1 it: 0 algorithms.ricci_community(G,alpha=0.6) 13
# mu: 1 it: 0 algorithms.ricci_community(G,alpha=0.75) 14
# mu: 1 it: 0 norm: 1843.6322843777714
# ---
# mu: 1 it: 1 algorithms.label_propagation(G) 15
# mu: 1 it: 1 algorithms.leiden(G) 15
# mu: 1 it: 1 algorithms.significance_communities(G) 16
# mu: 1 it: 1 algorithms.surprise_communities(G) 15
# mu: 1 it: 1 algorithms.greedy_modularity(G) 15
# mu: 1 it: 1 algorithms.paris(G) 15
# mu: 1 it: 1 algorithms.louvain(G,resolution=0.75,randomize=314159) 15
# mu: 1 it: 1 algorithms.louvain(G,resolution=0.75,randomize=2718) 15
# mu: 1 it: 1 algorithms.louvain(G,resolution=1.0,randomize=314159) 15
# mu: 1 it: 1 algorithms.louvain(G,resolution=1.0,randomize=2718) 15
# mu: 1 it: 1 algorithms.louvain(G,resolution=1.25,randomize=314159) 15
# mu: 1 it: 1 algorithms.louvain(G,resolution=1.25,randomize=2718) 15
# mu: 1 it: 1 algorithms.louvain(G,resolution=1.5,randomize=314159) 15
# mu: 1 it: 1 algorithms.louvain(G,resolution=1.5,randomize=2718) 15
# mu: 1 it: 1 algorithms.infomap(G) 15
# mu: 1 it: 1 algorithms.walktrap(G) 15
# mu: 1 it: 1 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 1 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 1 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.01,convergence_check_frequency=100) 16
# mu: 1 it: 1 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.001,convergence_check_frequency=100) 16
# mu: 1 it: 1 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.01,convergence_check_frequency=100) 17
# mu: 1 it: 1 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.001,convergence_check_frequency=100) 17
# mu: 1 it: 1 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.01,convergence_check_frequency=100) 18
# mu: 1 it: 1 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.001,convergence_check_frequency=100) 18
# mu: 1 it: 1 algorithms.em(G,k=11) 7
# mu: 1 it: 1 algorithms.em(G,k=41) 8
# mu: 1 it: 1 algorithms.em(G,k=40) 11
# mu: 1 it: 1 algorithms.em(G,k=12) 11
# mu: 1 it: 1 algorithms.sbm_dl(G) 12
# UNSUCCESSFUL algorithms.spinglass(G,spins=11)
# UNSUCCESSFUL algorithms.spinglass(G,spins=41)
# UNSUCCESSFUL algorithms.spinglass(G,spins=40)
# UNSUCCESSFUL algorithms.spinglass(G,spins=12)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.3)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.5)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.6)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.75)
# mu: 1 it: 1 norm: 351.5536943341657
# ---
# mu: 1 it: 2 algorithms.label_propagation(G) 15
# mu: 1 it: 2 algorithms.leiden(G) 15
# mu: 1 it: 2 algorithms.significance_communities(G) 15
# mu: 1 it: 2 algorithms.surprise_communities(G) 15
# mu: 1 it: 2 algorithms.greedy_modularity(G) 15
# mu: 1 it: 2 algorithms.paris(G) 15
# mu: 1 it: 2 algorithms.louvain(G,resolution=0.75,randomize=314159) 15
# mu: 1 it: 2 algorithms.louvain(G,resolution=0.75,randomize=2718) 15
# mu: 1 it: 2 algorithms.louvain(G,resolution=1.0,randomize=314159) 15
# mu: 1 it: 2 algorithms.louvain(G,resolution=1.0,randomize=2718) 15
# mu: 1 it: 2 algorithms.louvain(G,resolution=1.25,randomize=314159) 15
# mu: 1 it: 2 algorithms.louvain(G,resolution=1.25,randomize=2718) 15
# mu: 1 it: 2 algorithms.louvain(G,resolution=1.5,randomize=314159) 15
# mu: 1 it: 2 algorithms.louvain(G,resolution=1.5,randomize=2718) 15
# mu: 1 it: 2 algorithms.infomap(G) 15
# mu: 1 it: 2 algorithms.walktrap(G) 15
# mu: 1 it: 2 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 2 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 2 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 2 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 2 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 2 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 2 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.01,convergence_check_frequency=100) 16
# mu: 1 it: 2 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.001,convergence_check_frequency=100) 16
# mu: 1 it: 2 algorithms.em(G,k=11) 7
# mu: 1 it: 2 algorithms.em(G,k=41) 11
# mu: 1 it: 2 algorithms.em(G,k=40) 10
# mu: 1 it: 2 algorithms.em(G,k=12) 7
# mu: 1 it: 2 algorithms.sbm_dl(G) 12
# UNSUCCESSFUL algorithms.spinglass(G,spins=11)
# UNSUCCESSFUL algorithms.spinglass(G,spins=41)
# UNSUCCESSFUL algorithms.spinglass(G,spins=40)
# UNSUCCESSFUL algorithms.spinglass(G,spins=12)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.3)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.5)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.6)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.75)
# mu: 1 it: 2 norm: 68.22023160324215
# ---
# mu: 1 it: 3 algorithms.label_propagation(G) 15
# mu: 1 it: 3 algorithms.leiden(G) 15
# mu: 1 it: 3 algorithms.significance_communities(G) 15
# mu: 1 it: 3 algorithms.surprise_communities(G) 15
# mu: 1 it: 3 algorithms.greedy_modularity(G) 15
# mu: 1 it: 3 algorithms.paris(G) 15
# mu: 1 it: 3 algorithms.louvain(G,resolution=0.75,randomize=314159) 15
# mu: 1 it: 3 algorithms.louvain(G,resolution=0.75,randomize=2718) 15
# mu: 1 it: 3 algorithms.louvain(G,resolution=1.0,randomize=314159) 15
# mu: 1 it: 3 algorithms.louvain(G,resolution=1.0,randomize=2718) 15
# mu: 1 it: 3 algorithms.louvain(G,resolution=1.25,randomize=314159) 15
# mu: 1 it: 3 algorithms.louvain(G,resolution=1.25,randomize=2718) 15
# mu: 1 it: 3 algorithms.louvain(G,resolution=1.5,randomize=314159) 15
# mu: 1 it: 3 algorithms.louvain(G,resolution=1.5,randomize=2718) 15
# mu: 1 it: 3 algorithms.infomap(G) 15
# mu: 1 it: 3 algorithms.walktrap(G) 15
# mu: 1 it: 3 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 3 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 3 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 3 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 3 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 3 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 3 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.01,convergence_check_frequency=100) 17
# mu: 1 it: 3 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.001,convergence_check_frequency=100) 17
# mu: 1 it: 3 algorithms.em(G,k=11) 5
# mu: 1 it: 3 algorithms.em(G,k=41) 11
# mu: 1 it: 3 algorithms.em(G,k=40) 9
# mu: 1 it: 3 algorithms.em(G,k=12) 8
# mu: 1 it: 3 algorithms.sbm_dl(G) 12
# UNSUCCESSFUL algorithms.spinglass(G,spins=11)
# UNSUCCESSFUL algorithms.spinglass(G,spins=41)
# UNSUCCESSFUL algorithms.spinglass(G,spins=40)
# UNSUCCESSFUL algorithms.spinglass(G,spins=12)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.3)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.5)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.6)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.75)
# mu: 1 it: 3 norm: 51.146847410177685
# ---
# mu: 1 it: 4 algorithms.label_propagation(G) 15
# mu: 1 it: 4 algorithms.leiden(G) 15
# mu: 1 it: 4 algorithms.significance_communities(G) 15
# mu: 1 it: 4 algorithms.surprise_communities(G) 15
# mu: 1 it: 4 algorithms.greedy_modularity(G) 15
# mu: 1 it: 4 algorithms.paris(G) 15
# mu: 1 it: 4 algorithms.louvain(G,resolution=0.75,randomize=314159) 15
# mu: 1 it: 4 algorithms.louvain(G,resolution=0.75,randomize=2718) 15
# mu: 1 it: 4 algorithms.louvain(G,resolution=1.0,randomize=314159) 15
# mu: 1 it: 4 algorithms.louvain(G,resolution=1.0,randomize=2718) 15
# mu: 1 it: 4 algorithms.louvain(G,resolution=1.25,randomize=314159) 15
# mu: 1 it: 4 algorithms.louvain(G,resolution=1.25,randomize=2718) 15
# mu: 1 it: 4 algorithms.louvain(G,resolution=1.5,randomize=314159) 15
# mu: 1 it: 4 algorithms.louvain(G,resolution=1.5,randomize=2718) 15
# mu: 1 it: 4 algorithms.infomap(G) 15
# mu: 1 it: 4 algorithms.walktrap(G) 15
# mu: 1 it: 4 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 4 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 4 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 4 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 4 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 4 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 4 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 4 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 4 algorithms.em(G,k=11) 7
# mu: 1 it: 4 algorithms.em(G,k=41) 9
# mu: 1 it: 4 algorithms.em(G,k=40) 3
# mu: 1 it: 4 algorithms.em(G,k=12) 6
# mu: 1 it: 4 algorithms.sbm_dl(G) 18
# UNSUCCESSFUL algorithms.spinglass(G,spins=11)
# UNSUCCESSFUL algorithms.spinglass(G,spins=41)
# UNSUCCESSFUL algorithms.spinglass(G,spins=40)
# UNSUCCESSFUL algorithms.spinglass(G,spins=12)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.3)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.5)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.6)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.75)
# mu: 1 it: 4 norm: 47.37087712930804
# ---
# mu: 1 it: 5 algorithms.label_propagation(G) 15
# mu: 1 it: 5 algorithms.leiden(G) 15
# mu: 1 it: 5 algorithms.significance_communities(G) 15
# mu: 1 it: 5 algorithms.surprise_communities(G) 15
# mu: 1 it: 5 algorithms.greedy_modularity(G) 15
# mu: 1 it: 5 algorithms.paris(G) 15
# mu: 1 it: 5 algorithms.louvain(G,resolution=0.75,randomize=314159) 15
# mu: 1 it: 5 algorithms.louvain(G,resolution=0.75,randomize=2718) 15
# mu: 1 it: 5 algorithms.louvain(G,resolution=1.0,randomize=314159) 15
# mu: 1 it: 5 algorithms.louvain(G,resolution=1.0,randomize=2718) 15
# mu: 1 it: 5 algorithms.louvain(G,resolution=1.25,randomize=314159) 15
# mu: 1 it: 5 algorithms.louvain(G,resolution=1.25,randomize=2718) 15
# mu: 1 it: 5 algorithms.louvain(G,resolution=1.5,randomize=314159) 15
# mu: 1 it: 5 algorithms.louvain(G,resolution=1.5,randomize=2718) 15
# mu: 1 it: 5 algorithms.infomap(G) 15
# mu: 1 it: 5 algorithms.walktrap(G) 15
# mu: 1 it: 5 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 5 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 5 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 5 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 5 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 5 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 5 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.01,convergence_check_frequency=100) 17
# mu: 1 it: 5 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.001,convergence_check_frequency=100) 17
# mu: 1 it: 5 algorithms.em(G,k=11) 3
# mu: 1 it: 5 algorithms.em(G,k=41) 11
# mu: 1 it: 5 algorithms.em(G,k=40) 10
# mu: 1 it: 5 algorithms.em(G,k=12) 6
# mu: 1 it: 5 algorithms.sbm_dl(G) 13
# UNSUCCESSFUL algorithms.spinglass(G,spins=11)
# UNSUCCESSFUL algorithms.spinglass(G,spins=41)
# UNSUCCESSFUL algorithms.spinglass(G,spins=40)
# UNSUCCESSFUL algorithms.spinglass(G,spins=12)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.3)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.5)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.6)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.75)
# mu: 1 it: 5 norm: 50.438080851673966
# ---
# mu: 1 it: 6 algorithms.label_propagation(G) 15
# mu: 1 it: 6 algorithms.leiden(G) 15
# mu: 1 it: 6 algorithms.significance_communities(G) 15
# mu: 1 it: 6 algorithms.surprise_communities(G) 15
# mu: 1 it: 6 algorithms.greedy_modularity(G) 15
# mu: 1 it: 6 algorithms.paris(G) 15
# mu: 1 it: 6 algorithms.louvain(G,resolution=0.75,randomize=314159) 15
# mu: 1 it: 6 algorithms.louvain(G,resolution=0.75,randomize=2718) 15
# mu: 1 it: 6 algorithms.louvain(G,resolution=1.0,randomize=314159) 15
# mu: 1 it: 6 algorithms.louvain(G,resolution=1.0,randomize=2718) 15
# mu: 1 it: 6 algorithms.louvain(G,resolution=1.25,randomize=314159) 15
# mu: 1 it: 6 algorithms.louvain(G,resolution=1.25,randomize=2718) 15
# mu: 1 it: 6 algorithms.louvain(G,resolution=1.5,randomize=314159) 15
# mu: 1 it: 6 algorithms.louvain(G,resolution=1.5,randomize=2718) 15
# mu: 1 it: 6 algorithms.infomap(G) 15
# mu: 1 it: 6 algorithms.walktrap(G) 15
# mu: 1 it: 6 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 6 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 6 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 6 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 6 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 6 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 6 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.01,convergence_check_frequency=100) 16
# mu: 1 it: 6 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.001,convergence_check_frequency=100) 16
# mu: 1 it: 6 algorithms.em(G,k=11) 3
# mu: 1 it: 6 algorithms.em(G,k=41) 7
# mu: 1 it: 6 algorithms.em(G,k=40) 9
# mu: 1 it: 6 algorithms.em(G,k=12) 3
# mu: 1 it: 6 algorithms.sbm_dl(G) 13
# UNSUCCESSFUL algorithms.spinglass(G,spins=11)
# UNSUCCESSFUL algorithms.spinglass(G,spins=41)
# UNSUCCESSFUL algorithms.spinglass(G,spins=40)
# UNSUCCESSFUL algorithms.spinglass(G,spins=12)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.3)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.5)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.6)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.75)
# mu: 1 it: 6 norm: 48.33218389437829
# ---
# mu: 1 it: 7 algorithms.label_propagation(G) 15
# mu: 1 it: 7 algorithms.leiden(G) 15
# mu: 1 it: 7 algorithms.significance_communities(G) 15
# mu: 1 it: 7 algorithms.surprise_communities(G) 15
# mu: 1 it: 7 algorithms.greedy_modularity(G) 15
# mu: 1 it: 7 algorithms.paris(G) 15
# mu: 1 it: 7 algorithms.louvain(G,resolution=0.75,randomize=314159) 15
# mu: 1 it: 7 algorithms.louvain(G,resolution=0.75,randomize=2718) 15
# mu: 1 it: 7 algorithms.louvain(G,resolution=1.0,randomize=314159) 15
# mu: 1 it: 7 algorithms.louvain(G,resolution=1.0,randomize=2718) 15
# mu: 1 it: 7 algorithms.louvain(G,resolution=1.25,randomize=314159) 15
# mu: 1 it: 7 algorithms.louvain(G,resolution=1.25,randomize=2718) 15
# mu: 1 it: 7 algorithms.louvain(G,resolution=1.5,randomize=314159) 15
# mu: 1 it: 7 algorithms.louvain(G,resolution=1.5,randomize=2718) 15
# mu: 1 it: 7 algorithms.infomap(G) 15
# mu: 1 it: 7 algorithms.walktrap(G) 15
# mu: 1 it: 7 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 7 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 7 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 7 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 7 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 7 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 7 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.01,convergence_check_frequency=100) 17
# mu: 1 it: 7 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.001,convergence_check_frequency=100) 16
# mu: 1 it: 7 algorithms.em(G,k=11) 3
# mu: 1 it: 7 algorithms.em(G,k=41) 8
# mu: 1 it: 7 algorithms.em(G,k=40) 8
# mu: 1 it: 7 algorithms.em(G,k=12) 9
# mu: 1 it: 7 algorithms.sbm_dl(G) 11
# UNSUCCESSFUL algorithms.spinglass(G,spins=11)
# UNSUCCESSFUL algorithms.spinglass(G,spins=41)
# UNSUCCESSFUL algorithms.spinglass(G,spins=40)
# UNSUCCESSFUL algorithms.spinglass(G,spins=12)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.3)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.5)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.6)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.75)
# mu: 1 it: 7 norm: 59.732738092272314
# ---
# mu: 1 it: 8 algorithms.label_propagation(G) 15
# mu: 1 it: 8 algorithms.leiden(G) 15
# mu: 1 it: 8 algorithms.significance_communities(G) 15
# mu: 1 it: 8 algorithms.surprise_communities(G) 15
# mu: 1 it: 8 algorithms.greedy_modularity(G) 15
# mu: 1 it: 8 algorithms.paris(G) 15
# mu: 1 it: 8 algorithms.louvain(G,resolution=0.75,randomize=314159) 15
# mu: 1 it: 8 algorithms.louvain(G,resolution=0.75,randomize=2718) 15
# mu: 1 it: 8 algorithms.louvain(G,resolution=1.0,randomize=314159) 15
# mu: 1 it: 8 algorithms.louvain(G,resolution=1.0,randomize=2718) 15
# mu: 1 it: 8 algorithms.louvain(G,resolution=1.25,randomize=314159) 15
# mu: 1 it: 8 algorithms.louvain(G,resolution=1.25,randomize=2718) 15
# mu: 1 it: 8 algorithms.louvain(G,resolution=1.5,randomize=314159) 15
# mu: 1 it: 8 algorithms.louvain(G,resolution=1.5,randomize=2718) 15
# mu: 1 it: 8 algorithms.infomap(G) 15
# mu: 1 it: 8 algorithms.walktrap(G) 15
# mu: 1 it: 8 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 8 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 8 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 8 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 8 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 8 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 8 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 8 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 8 algorithms.em(G,k=11) 4
# mu: 1 it: 8 algorithms.em(G,k=41) 8
# mu: 1 it: 8 algorithms.em(G,k=40) 8
# mu: 1 it: 8 algorithms.em(G,k=12) 7
# mu: 1 it: 8 algorithms.sbm_dl(G) 13
# UNSUCCESSFUL algorithms.spinglass(G,spins=11)
# UNSUCCESSFUL algorithms.spinglass(G,spins=41)
# UNSUCCESSFUL algorithms.spinglass(G,spins=40)
# UNSUCCESSFUL algorithms.spinglass(G,spins=12)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.3)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.5)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.6)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.75)
# mu: 1 it: 8 norm: 45.2990066116245
# ---
# mu: 1 it: 9 algorithms.label_propagation(G) 15
# mu: 1 it: 9 algorithms.leiden(G) 15
# mu: 1 it: 9 algorithms.significance_communities(G) 15
# mu: 1 it: 9 algorithms.surprise_communities(G) 15
# mu: 1 it: 9 algorithms.greedy_modularity(G) 15
# mu: 1 it: 9 algorithms.paris(G) 15
# mu: 1 it: 9 algorithms.louvain(G,resolution=0.75,randomize=314159) 15
# mu: 1 it: 9 algorithms.louvain(G,resolution=0.75,randomize=2718) 15
# mu: 1 it: 9 algorithms.louvain(G,resolution=1.0,randomize=314159) 15
# mu: 1 it: 9 algorithms.louvain(G,resolution=1.0,randomize=2718) 15
# mu: 1 it: 9 algorithms.louvain(G,resolution=1.25,randomize=314159) 15
# mu: 1 it: 9 algorithms.louvain(G,resolution=1.25,randomize=2718) 15
# mu: 1 it: 9 algorithms.louvain(G,resolution=1.5,randomize=314159) 15
# mu: 1 it: 9 algorithms.louvain(G,resolution=1.5,randomize=2718) 15
# mu: 1 it: 9 algorithms.infomap(G) 15
# mu: 1 it: 9 algorithms.walktrap(G) 15
# mu: 1 it: 9 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 9 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 9 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 9 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 9 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 9 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 9 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.01,convergence_check_frequency=100) 16
# mu: 1 it: 9 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.001,convergence_check_frequency=100) 16
# mu: 1 it: 9 algorithms.em(G,k=11) 5
# mu: 1 it: 9 algorithms.em(G,k=41) 3
# mu: 1 it: 9 algorithms.em(G,k=40) 9
# mu: 1 it: 9 algorithms.em(G,k=12) 7
# mu: 1 it: 9 algorithms.sbm_dl(G) 16
# UNSUCCESSFUL algorithms.spinglass(G,spins=11)
# UNSUCCESSFUL algorithms.spinglass(G,spins=41)
# UNSUCCESSFUL algorithms.spinglass(G,spins=40)
# UNSUCCESSFUL algorithms.spinglass(G,spins=12)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.3)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.5)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.6)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.75)
# mu: 1 it: 9 norm: 44.8998886412873
# ---
# mu: 1 it: 10 algorithms.label_propagation(G) 15
# mu: 1 it: 10 algorithms.leiden(G) 15
# mu: 1 it: 10 algorithms.significance_communities(G) 15
# mu: 1 it: 10 algorithms.surprise_communities(G) 15
# mu: 1 it: 10 algorithms.greedy_modularity(G) 15
# mu: 1 it: 10 algorithms.paris(G) 15
# mu: 1 it: 10 algorithms.louvain(G,resolution=0.75,randomize=314159) 15
# mu: 1 it: 10 algorithms.louvain(G,resolution=0.75,randomize=2718) 15
# mu: 1 it: 10 algorithms.louvain(G,resolution=1.0,randomize=314159) 15
# mu: 1 it: 10 algorithms.louvain(G,resolution=1.0,randomize=2718) 15
# mu: 1 it: 10 algorithms.louvain(G,resolution=1.25,randomize=314159) 15
# mu: 1 it: 10 algorithms.louvain(G,resolution=1.25,randomize=2718) 15
# mu: 1 it: 10 algorithms.louvain(G,resolution=1.5,randomize=314159) 15
# mu: 1 it: 10 algorithms.louvain(G,resolution=1.5,randomize=2718) 15
# mu: 1 it: 10 algorithms.infomap(G) 15
# mu: 1 it: 10 algorithms.walktrap(G) 15
# mu: 1 it: 10 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 10 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 10 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 10 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 10 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 10 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 10 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.01,convergence_check_frequency=100) 16
# mu: 1 it: 10 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.001,convergence_check_frequency=100) 16
# mu: 1 it: 10 algorithms.em(G,k=11) 7
# mu: 1 it: 10 algorithms.em(G,k=41) 8
# mu: 1 it: 10 algorithms.em(G,k=40) 6
# mu: 1 it: 10 algorithms.em(G,k=12) 6
# mu: 1 it: 10 algorithms.sbm_dl(G) 11
# UNSUCCESSFUL algorithms.spinglass(G,spins=11)
# UNSUCCESSFUL algorithms.spinglass(G,spins=41)
# UNSUCCESSFUL algorithms.spinglass(G,spins=40)
# UNSUCCESSFUL algorithms.spinglass(G,spins=12)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.3)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.5)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.6)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.75)
# mu: 1 it: 10 norm: 48.41487374764082
# ---
# mu: 1 it: 11 algorithms.label_propagation(G) 15
# mu: 1 it: 11 algorithms.leiden(G) 15
# mu: 1 it: 11 algorithms.significance_communities(G) 15
# mu: 1 it: 11 algorithms.surprise_communities(G) 15
# mu: 1 it: 11 algorithms.greedy_modularity(G) 15
# mu: 1 it: 11 algorithms.paris(G) 15
# mu: 1 it: 11 algorithms.louvain(G,resolution=0.75,randomize=314159) 15
# mu: 1 it: 11 algorithms.louvain(G,resolution=0.75,randomize=2718) 15
# mu: 1 it: 11 algorithms.louvain(G,resolution=1.0,randomize=314159) 15
# mu: 1 it: 11 algorithms.louvain(G,resolution=1.0,randomize=2718) 15
# mu: 1 it: 11 algorithms.louvain(G,resolution=1.25,randomize=314159) 15
# mu: 1 it: 11 algorithms.louvain(G,resolution=1.25,randomize=2718) 15
# mu: 1 it: 11 algorithms.louvain(G,resolution=1.5,randomize=314159) 15
# mu: 1 it: 11 algorithms.louvain(G,resolution=1.5,randomize=2718) 15
# mu: 1 it: 11 algorithms.infomap(G) 15
# mu: 1 it: 11 algorithms.walktrap(G) 15
# mu: 1 it: 11 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 11 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 11 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 11 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 11 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 11 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 11 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.01,convergence_check_frequency=100) 17
# mu: 1 it: 11 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.001,convergence_check_frequency=100) 17
# mu: 1 it: 11 algorithms.em(G,k=11) 7
# mu: 1 it: 11 algorithms.em(G,k=41) 10
# mu: 1 it: 11 algorithms.em(G,k=40) 8
# mu: 1 it: 11 algorithms.em(G,k=12) 6
# mu: 1 it: 11 algorithms.sbm_dl(G) 12
# UNSUCCESSFUL algorithms.spinglass(G,spins=11)
# UNSUCCESSFUL algorithms.spinglass(G,spins=41)
# UNSUCCESSFUL algorithms.spinglass(G,spins=40)
# UNSUCCESSFUL algorithms.spinglass(G,spins=12)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.3)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.5)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.6)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.75)
# mu: 1 it: 11 norm: 41.71330722922842
# ---
# mu: 1 it: 12 algorithms.label_propagation(G) 15
# mu: 1 it: 12 algorithms.leiden(G) 15
# mu: 1 it: 12 algorithms.significance_communities(G) 15
# mu: 1 it: 12 algorithms.surprise_communities(G) 15
# mu: 1 it: 12 algorithms.greedy_modularity(G) 15
# mu: 1 it: 12 algorithms.paris(G) 15
# mu: 1 it: 12 algorithms.louvain(G,resolution=0.75,randomize=314159) 15
# mu: 1 it: 12 algorithms.louvain(G,resolution=0.75,randomize=2718) 15
# mu: 1 it: 12 algorithms.louvain(G,resolution=1.0,randomize=314159) 15
# mu: 1 it: 12 algorithms.louvain(G,resolution=1.0,randomize=2718) 15
# mu: 1 it: 12 algorithms.louvain(G,resolution=1.25,randomize=314159) 15
# mu: 1 it: 12 algorithms.louvain(G,resolution=1.25,randomize=2718) 15
# mu: 1 it: 12 algorithms.louvain(G,resolution=1.5,randomize=314159) 15
# mu: 1 it: 12 algorithms.louvain(G,resolution=1.5,randomize=2718) 15
# mu: 1 it: 12 algorithms.infomap(G) 15
# mu: 1 it: 12 algorithms.walktrap(G) 15
# mu: 1 it: 12 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 12 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 12 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 12 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 12 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 12 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 12 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 12 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 12 algorithms.em(G,k=11) 8
# mu: 1 it: 12 algorithms.em(G,k=41) 9
# mu: 1 it: 12 algorithms.em(G,k=40) 8
# mu: 1 it: 12 algorithms.em(G,k=12) 7
# mu: 1 it: 12 algorithms.sbm_dl(G) 11
# UNSUCCESSFUL algorithms.spinglass(G,spins=11)
# UNSUCCESSFUL algorithms.spinglass(G,spins=41)
# UNSUCCESSFUL algorithms.spinglass(G,spins=40)
# UNSUCCESSFUL algorithms.spinglass(G,spins=12)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.3)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.5)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.6)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.75)
# mu: 1 it: 12 norm: 38.262252939417984
# ---
# mu: 1 it: 13 algorithms.label_propagation(G) 15
# mu: 1 it: 13 algorithms.leiden(G) 15
# mu: 1 it: 13 algorithms.significance_communities(G) 15
# mu: 1 it: 13 algorithms.surprise_communities(G) 15
# mu: 1 it: 13 algorithms.greedy_modularity(G) 15
# mu: 1 it: 13 algorithms.paris(G) 15
# mu: 1 it: 13 algorithms.louvain(G,resolution=0.75,randomize=314159) 15
# mu: 1 it: 13 algorithms.louvain(G,resolution=0.75,randomize=2718) 15
# mu: 1 it: 13 algorithms.louvain(G,resolution=1.0,randomize=314159) 15
# mu: 1 it: 13 algorithms.louvain(G,resolution=1.0,randomize=2718) 15
# mu: 1 it: 13 algorithms.louvain(G,resolution=1.25,randomize=314159) 15
# mu: 1 it: 13 algorithms.louvain(G,resolution=1.25,randomize=2718) 15
# mu: 1 it: 13 algorithms.louvain(G,resolution=1.5,randomize=314159) 15
# mu: 1 it: 13 algorithms.louvain(G,resolution=1.5,randomize=2718) 15
# mu: 1 it: 13 algorithms.infomap(G) 15
# mu: 1 it: 13 algorithms.walktrap(G) 15
# mu: 1 it: 13 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 13 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 13 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 13 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 13 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 13 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 13 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.01,convergence_check_frequency=100) 17
# mu: 1 it: 13 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.001,convergence_check_frequency=100) 17
# mu: 1 it: 13 algorithms.em(G,k=11) 8
# mu: 1 it: 13 algorithms.em(G,k=41) 8
# mu: 1 it: 13 algorithms.em(G,k=40) 10
# mu: 1 it: 13 algorithms.em(G,k=12) 3
# mu: 1 it: 13 algorithms.sbm_dl(G) 13
# UNSUCCESSFUL algorithms.spinglass(G,spins=11)
# UNSUCCESSFUL algorithms.spinglass(G,spins=41)
# UNSUCCESSFUL algorithms.spinglass(G,spins=40)
# UNSUCCESSFUL algorithms.spinglass(G,spins=12)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.3)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.5)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.6)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.75)
# mu: 1 it: 13 norm: 41.80908992073375
# ---
# mu: 1 it: 14 algorithms.label_propagation(G) 15
# mu: 1 it: 14 algorithms.leiden(G) 15
# mu: 1 it: 14 algorithms.significance_communities(G) 15
# mu: 1 it: 14 algorithms.surprise_communities(G) 15
# mu: 1 it: 14 algorithms.greedy_modularity(G) 15
# mu: 1 it: 14 algorithms.paris(G) 15
# mu: 1 it: 14 algorithms.louvain(G,resolution=0.75,randomize=314159) 15
# mu: 1 it: 14 algorithms.louvain(G,resolution=0.75,randomize=2718) 15
# mu: 1 it: 14 algorithms.louvain(G,resolution=1.0,randomize=314159) 15
# mu: 1 it: 14 algorithms.louvain(G,resolution=1.0,randomize=2718) 15
# mu: 1 it: 14 algorithms.louvain(G,resolution=1.25,randomize=314159) 15
# mu: 1 it: 14 algorithms.louvain(G,resolution=1.25,randomize=2718) 15
# mu: 1 it: 14 algorithms.louvain(G,resolution=1.5,randomize=314159) 15
# mu: 1 it: 14 algorithms.louvain(G,resolution=1.5,randomize=2718) 15
# mu: 1 it: 14 algorithms.infomap(G) 15
# mu: 1 it: 14 algorithms.walktrap(G) 15
# mu: 1 it: 14 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 14 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 14 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 14 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 14 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 14 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 14 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 14 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 14 algorithms.em(G,k=11) 7
# mu: 1 it: 14 algorithms.em(G,k=41) 3
# mu: 1 it: 14 algorithms.em(G,k=40) 11
# mu: 1 it: 14 algorithms.em(G,k=12) 3
# mu: 1 it: 14 algorithms.sbm_dl(G) 12
# UNSUCCESSFUL algorithms.spinglass(G,spins=11)
# UNSUCCESSFUL algorithms.spinglass(G,spins=41)
# UNSUCCESSFUL algorithms.spinglass(G,spins=40)
# UNSUCCESSFUL algorithms.spinglass(G,spins=12)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.3)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.5)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.6)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.75)
# mu: 1 it: 14 norm: 43.42810150121693
# ---
# mu: 1 it: 15 algorithms.label_propagation(G) 15
# mu: 1 it: 15 algorithms.leiden(G) 15
# mu: 1 it: 15 algorithms.significance_communities(G) 15
# mu: 1 it: 15 algorithms.surprise_communities(G) 15
# mu: 1 it: 15 algorithms.greedy_modularity(G) 15
# mu: 1 it: 15 algorithms.paris(G) 15
# mu: 1 it: 15 algorithms.louvain(G,resolution=0.75,randomize=314159) 15
# mu: 1 it: 15 algorithms.louvain(G,resolution=0.75,randomize=2718) 15
# mu: 1 it: 15 algorithms.louvain(G,resolution=1.0,randomize=314159) 15
# mu: 1 it: 15 algorithms.louvain(G,resolution=1.0,randomize=2718) 15
# mu: 1 it: 15 algorithms.louvain(G,resolution=1.25,randomize=314159) 15
# mu: 1 it: 15 algorithms.louvain(G,resolution=1.25,randomize=2718) 15
# mu: 1 it: 15 algorithms.louvain(G,resolution=1.5,randomize=314159) 15
# mu: 1 it: 15 algorithms.louvain(G,resolution=1.5,randomize=2718) 15
# mu: 1 it: 15 algorithms.infomap(G) 15
# mu: 1 it: 15 algorithms.walktrap(G) 15
# mu: 1 it: 15 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 15 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 15 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 15 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 15 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 15 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 15 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.01,convergence_check_frequency=100) 17
# mu: 1 it: 15 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.001,convergence_check_frequency=100) 17
# mu: 1 it: 15 algorithms.em(G,k=11) 6
# mu: 1 it: 15 algorithms.em(G,k=41) 8
# mu: 1 it: 15 algorithms.em(G,k=40) 8
# mu: 1 it: 15 algorithms.em(G,k=12) 3
# mu: 1 it: 15 algorithms.sbm_dl(G) 12
# UNSUCCESSFUL algorithms.spinglass(G,spins=11)
# UNSUCCESSFUL algorithms.spinglass(G,spins=41)
# UNSUCCESSFUL algorithms.spinglass(G,spins=40)
# UNSUCCESSFUL algorithms.spinglass(G,spins=12)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.3)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.5)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.6)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.75)
# mu: 1 it: 15 norm: 39.74921382870358
# ---
# mu: 1 it: 16 algorithms.label_propagation(G) 15
# mu: 1 it: 16 algorithms.leiden(G) 15
# mu: 1 it: 16 algorithms.significance_communities(G) 15
# mu: 1 it: 16 algorithms.surprise_communities(G) 15
# mu: 1 it: 16 algorithms.greedy_modularity(G) 15
# mu: 1 it: 16 algorithms.paris(G) 15
# mu: 1 it: 16 algorithms.louvain(G,resolution=0.75,randomize=314159) 15
# mu: 1 it: 16 algorithms.louvain(G,resolution=0.75,randomize=2718) 15
# mu: 1 it: 16 algorithms.louvain(G,resolution=1.0,randomize=314159) 15
# mu: 1 it: 16 algorithms.louvain(G,resolution=1.0,randomize=2718) 15
# mu: 1 it: 16 algorithms.louvain(G,resolution=1.25,randomize=314159) 15
# mu: 1 it: 16 algorithms.louvain(G,resolution=1.25,randomize=2718) 15
# mu: 1 it: 16 algorithms.louvain(G,resolution=1.5,randomize=314159) 15
# mu: 1 it: 16 algorithms.louvain(G,resolution=1.5,randomize=2718) 15
# mu: 1 it: 16 algorithms.infomap(G) 15
# mu: 1 it: 16 algorithms.walktrap(G) 15
# mu: 1 it: 16 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 16 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 16 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 16 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 16 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 16 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 16 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.01,convergence_check_frequency=100) 16
# mu: 1 it: 16 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.001,convergence_check_frequency=100) 16
# mu: 1 it: 16 algorithms.em(G,k=11) 7
# mu: 1 it: 16 algorithms.em(G,k=41) 10
# mu: 1 it: 16 algorithms.em(G,k=40) 8
# mu: 1 it: 16 algorithms.em(G,k=12) 6
# mu: 1 it: 16 algorithms.sbm_dl(G) 12
# UNSUCCESSFUL algorithms.spinglass(G,spins=11)
# UNSUCCESSFUL algorithms.spinglass(G,spins=41)
# UNSUCCESSFUL algorithms.spinglass(G,spins=40)
# UNSUCCESSFUL algorithms.spinglass(G,spins=12)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.3)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.5)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.6)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.75)
# mu: 1 it: 16 norm: 51.84592558726288
# ---
# mu: 1 it: 17 algorithms.label_propagation(G) 15
# mu: 1 it: 17 algorithms.leiden(G) 15
# mu: 1 it: 17 algorithms.significance_communities(G) 15
# mu: 1 it: 17 algorithms.surprise_communities(G) 15
# mu: 1 it: 17 algorithms.greedy_modularity(G) 15
# mu: 1 it: 17 algorithms.paris(G) 15
# mu: 1 it: 17 algorithms.louvain(G,resolution=0.75,randomize=314159) 15
# mu: 1 it: 17 algorithms.louvain(G,resolution=0.75,randomize=2718) 15
# mu: 1 it: 17 algorithms.louvain(G,resolution=1.0,randomize=314159) 15
# mu: 1 it: 17 algorithms.louvain(G,resolution=1.0,randomize=2718) 15
# mu: 1 it: 17 algorithms.louvain(G,resolution=1.25,randomize=314159) 15
# mu: 1 it: 17 algorithms.louvain(G,resolution=1.25,randomize=2718) 15
# mu: 1 it: 17 algorithms.louvain(G,resolution=1.5,randomize=314159) 15
# mu: 1 it: 17 algorithms.louvain(G,resolution=1.5,randomize=2718) 15
# mu: 1 it: 17 algorithms.infomap(G) 15
# mu: 1 it: 17 algorithms.walktrap(G) 15
# mu: 1 it: 17 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 17 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 17 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 17 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 17 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 17 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 17 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.01,convergence_check_frequency=100) 16
# mu: 1 it: 17 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.001,convergence_check_frequency=100) 16
# mu: 1 it: 17 algorithms.em(G,k=11) 8
# mu: 1 it: 17 algorithms.em(G,k=41) 8
# mu: 1 it: 17 algorithms.em(G,k=40) 8
# mu: 1 it: 17 algorithms.em(G,k=12) 7
# mu: 1 it: 17 algorithms.sbm_dl(G) 11
# UNSUCCESSFUL algorithms.spinglass(G,spins=11)
# UNSUCCESSFUL algorithms.spinglass(G,spins=41)
# UNSUCCESSFUL algorithms.spinglass(G,spins=40)
# UNSUCCESSFUL algorithms.spinglass(G,spins=12)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.3)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.5)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.6)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.75)
# mu: 1 it: 17 norm: 42.23742416388575
# ---
# mu: 1 it: 18 algorithms.label_propagation(G) 15
# mu: 1 it: 18 algorithms.leiden(G) 15
# mu: 1 it: 18 algorithms.significance_communities(G) 15
# mu: 1 it: 18 algorithms.surprise_communities(G) 15
# mu: 1 it: 18 algorithms.greedy_modularity(G) 15
# mu: 1 it: 18 algorithms.paris(G) 15
# mu: 1 it: 18 algorithms.louvain(G,resolution=0.75,randomize=314159) 15
# mu: 1 it: 18 algorithms.louvain(G,resolution=0.75,randomize=2718) 15
# mu: 1 it: 18 algorithms.louvain(G,resolution=1.0,randomize=314159) 15
# mu: 1 it: 18 algorithms.louvain(G,resolution=1.0,randomize=2718) 15
# mu: 1 it: 18 algorithms.louvain(G,resolution=1.25,randomize=314159) 15
# mu: 1 it: 18 algorithms.louvain(G,resolution=1.25,randomize=2718) 15
# mu: 1 it: 18 algorithms.louvain(G,resolution=1.5,randomize=314159) 15
# mu: 1 it: 18 algorithms.louvain(G,resolution=1.5,randomize=2718) 15
# mu: 1 it: 18 algorithms.infomap(G) 15
# mu: 1 it: 18 algorithms.walktrap(G) 15
# mu: 1 it: 18 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 18 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 18 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 18 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 18 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 18 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 18 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.01,convergence_check_frequency=100) 16
# mu: 1 it: 18 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.001,convergence_check_frequency=100) 16
# mu: 1 it: 18 algorithms.em(G,k=11) 9
# mu: 1 it: 18 algorithms.em(G,k=41) 10
# mu: 1 it: 18 algorithms.em(G,k=40) 10
# mu: 1 it: 18 algorithms.em(G,k=12) 7
# mu: 1 it: 18 algorithms.sbm_dl(G) 11
# UNSUCCESSFUL algorithms.spinglass(G,spins=11)
# UNSUCCESSFUL algorithms.spinglass(G,spins=41)
# UNSUCCESSFUL algorithms.spinglass(G,spins=40)
# UNSUCCESSFUL algorithms.spinglass(G,spins=12)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.3)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.5)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.6)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.75)
# mu: 1 it: 18 norm: 48.80573736764972
# ---
# mu: 1 it: 19 algorithms.label_propagation(G) 15
# mu: 1 it: 19 algorithms.leiden(G) 15
# mu: 1 it: 19 algorithms.significance_communities(G) 15
# mu: 1 it: 19 algorithms.surprise_communities(G) 15
# mu: 1 it: 19 algorithms.greedy_modularity(G) 15
# mu: 1 it: 19 algorithms.paris(G) 15
# mu: 1 it: 19 algorithms.louvain(G,resolution=0.75,randomize=314159) 15
# mu: 1 it: 19 algorithms.louvain(G,resolution=0.75,randomize=2718) 15
# mu: 1 it: 19 algorithms.louvain(G,resolution=1.0,randomize=314159) 15
# mu: 1 it: 19 algorithms.louvain(G,resolution=1.0,randomize=2718) 15
# mu: 1 it: 19 algorithms.louvain(G,resolution=1.25,randomize=314159) 15
# mu: 1 it: 19 algorithms.louvain(G,resolution=1.25,randomize=2718) 15
# mu: 1 it: 19 algorithms.louvain(G,resolution=1.5,randomize=314159) 15
# mu: 1 it: 19 algorithms.louvain(G,resolution=1.5,randomize=2718) 15
# mu: 1 it: 19 algorithms.infomap(G) 15
# mu: 1 it: 19 algorithms.walktrap(G) 15
# mu: 1 it: 19 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 1 it: 19 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 1 it: 19 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.01,convergence_check_frequency=100) 15
# ...
# mu: 4 it: 13 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.01,convergence_check_frequency=100) 16
# mu: 4 it: 13 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.001,convergence_check_frequency=100) 16
# mu: 4 it: 13 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.01,convergence_check_frequency=100) 16
# mu: 4 it: 13 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.001,convergence_check_frequency=100) 16
# mu: 4 it: 13 algorithms.em(G,k=11) 7
# mu: 4 it: 13 algorithms.em(G,k=41) 13
# mu: 4 it: 13 algorithms.em(G,k=40) 10
# mu: 4 it: 13 algorithms.em(G,k=12) 9
# mu: 4 it: 13 algorithms.sbm_dl(G) 11
# UNSUCCESSFUL algorithms.spinglass(G,spins=11)
# UNSUCCESSFUL algorithms.spinglass(G,spins=41)
# UNSUCCESSFUL algorithms.spinglass(G,spins=40)
# UNSUCCESSFUL algorithms.spinglass(G,spins=12)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.3)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.5)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.6)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.75)
# mu: 4 it: 13 norm: 44.83302354291979
# ---
# mu: 4 it: 14 algorithms.label_propagation(G) 14
# mu: 4 it: 14 algorithms.leiden(G) 14
# mu: 4 it: 14 algorithms.significance_communities(G) 14
# mu: 4 it: 14 algorithms.surprise_communities(G) 14
# mu: 4 it: 14 algorithms.greedy_modularity(G) 14
# mu: 4 it: 14 algorithms.paris(G) 14
# mu: 4 it: 14 algorithms.louvain(G,resolution=0.75,randomize=314159) 14
# mu: 4 it: 14 algorithms.louvain(G,resolution=0.75,randomize=2718) 14
# mu: 4 it: 14 algorithms.louvain(G,resolution=1.0,randomize=314159) 14
# mu: 4 it: 14 algorithms.louvain(G,resolution=1.0,randomize=2718) 14
# mu: 4 it: 14 algorithms.louvain(G,resolution=1.25,randomize=314159) 14
# mu: 4 it: 14 algorithms.louvain(G,resolution=1.25,randomize=2718) 14
# mu: 4 it: 14 algorithms.louvain(G,resolution=1.5,randomize=314159) 14
# mu: 4 it: 14 algorithms.louvain(G,resolution=1.5,randomize=2718) 14
# mu: 4 it: 14 algorithms.infomap(G) 14
# mu: 4 it: 14 algorithms.walktrap(G) 14
# mu: 4 it: 14 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 4 it: 14 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 4 it: 14 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 4 it: 14 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 4 it: 14 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.01,convergence_check_frequency=100) 16
# mu: 4 it: 14 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.001,convergence_check_frequency=100) 16
# mu: 4 it: 14 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.01,convergence_check_frequency=100) 16
# mu: 4 it: 14 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.001,convergence_check_frequency=100) 16
# mu: 4 it: 14 algorithms.em(G,k=11) 7
# mu: 4 it: 14 algorithms.em(G,k=41) 11
# mu: 4 it: 14 algorithms.em(G,k=40) 11
# mu: 4 it: 14 algorithms.em(G,k=12) 7
# mu: 4 it: 14 algorithms.sbm_dl(G) 10
# UNSUCCESSFUL algorithms.spinglass(G,spins=11)
# UNSUCCESSFUL algorithms.spinglass(G,spins=41)
# UNSUCCESSFUL algorithms.spinglass(G,spins=40)
# UNSUCCESSFUL algorithms.spinglass(G,spins=12)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.3)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.5)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.6)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.75)
# mu: 4 it: 14 norm: 52.630789467763066
# ---
# mu: 4 it: 15 algorithms.label_propagation(G) 14
# mu: 4 it: 15 algorithms.leiden(G) 14
# mu: 4 it: 15 algorithms.significance_communities(G) 14
# mu: 4 it: 15 algorithms.surprise_communities(G) 14
# mu: 4 it: 15 algorithms.greedy_modularity(G) 14
# mu: 4 it: 15 algorithms.paris(G) 14
# mu: 4 it: 15 algorithms.louvain(G,resolution=0.75,randomize=314159) 14
# mu: 4 it: 15 algorithms.louvain(G,resolution=0.75,randomize=2718) 14
# mu: 4 it: 15 algorithms.louvain(G,resolution=1.0,randomize=314159) 14
# mu: 4 it: 15 algorithms.louvain(G,resolution=1.0,randomize=2718) 14
# mu: 4 it: 15 algorithms.louvain(G,resolution=1.25,randomize=314159) 14
# mu: 4 it: 15 algorithms.louvain(G,resolution=1.25,randomize=2718) 14
# mu: 4 it: 15 algorithms.louvain(G,resolution=1.5,randomize=314159) 14
# mu: 4 it: 15 algorithms.louvain(G,resolution=1.5,randomize=2718) 14
# mu: 4 it: 15 algorithms.infomap(G) 14
# mu: 4 it: 15 algorithms.walktrap(G) 14
# mu: 4 it: 15 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 4 it: 15 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 4 it: 15 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 4 it: 15 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 4 it: 15 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.01,convergence_check_frequency=100) 16
# mu: 4 it: 15 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.001,convergence_check_frequency=100) 16
# mu: 4 it: 15 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.01,convergence_check_frequency=100) 16
# mu: 4 it: 15 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.001,convergence_check_frequency=100) 16
# mu: 4 it: 15 algorithms.em(G,k=11) 7
# mu: 4 it: 15 algorithms.em(G,k=41) 11
# mu: 4 it: 15 algorithms.em(G,k=40) 8
# mu: 4 it: 15 algorithms.em(G,k=12) 6
# mu: 4 it: 15 algorithms.sbm_dl(G) 10
# UNSUCCESSFUL algorithms.spinglass(G,spins=11)
# UNSUCCESSFUL algorithms.spinglass(G,spins=41)
# UNSUCCESSFUL algorithms.spinglass(G,spins=40)
# UNSUCCESSFUL algorithms.spinglass(G,spins=12)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.3)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.5)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.6)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.75)
# mu: 4 it: 15 norm: 57.39337940912697
# ---
# mu: 4 it: 16 algorithms.label_propagation(G) 14
# mu: 4 it: 16 algorithms.leiden(G) 14
# mu: 4 it: 16 algorithms.significance_communities(G) 14
# mu: 4 it: 16 algorithms.surprise_communities(G) 14
# mu: 4 it: 16 algorithms.greedy_modularity(G) 14
# mu: 4 it: 16 algorithms.paris(G) 14
# mu: 4 it: 16 algorithms.louvain(G,resolution=0.75,randomize=314159) 14
# mu: 4 it: 16 algorithms.louvain(G,resolution=0.75,randomize=2718) 14
# mu: 4 it: 16 algorithms.louvain(G,resolution=1.0,randomize=314159) 14
# mu: 4 it: 16 algorithms.louvain(G,resolution=1.0,randomize=2718) 14
# mu: 4 it: 16 algorithms.louvain(G,resolution=1.25,randomize=314159) 14
# mu: 4 it: 16 algorithms.louvain(G,resolution=1.25,randomize=2718) 14
# mu: 4 it: 16 algorithms.louvain(G,resolution=1.5,randomize=314159) 14
# mu: 4 it: 16 algorithms.louvain(G,resolution=1.5,randomize=2718) 14
# mu: 4 it: 16 algorithms.infomap(G) 14
# mu: 4 it: 16 algorithms.walktrap(G) 14
# mu: 4 it: 16 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 4 it: 16 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 4 it: 16 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 4 it: 16 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 4 it: 16 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 4 it: 16 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 4 it: 16 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.01,convergence_check_frequency=100) 16
# mu: 4 it: 16 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.001,convergence_check_frequency=100) 16
# mu: 4 it: 16 algorithms.em(G,k=11) 7
# mu: 4 it: 16 algorithms.em(G,k=41) 10
# mu: 4 it: 16 algorithms.em(G,k=40) 9
# mu: 4 it: 16 algorithms.em(G,k=12) 9
# mu: 4 it: 16 algorithms.sbm_dl(G) 11
# UNSUCCESSFUL algorithms.spinglass(G,spins=11)
# UNSUCCESSFUL algorithms.spinglass(G,spins=41)
# UNSUCCESSFUL algorithms.spinglass(G,spins=40)
# UNSUCCESSFUL algorithms.spinglass(G,spins=12)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.3)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.5)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.6)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.75)
# mu: 4 it: 16 norm: 53.40411969127476
# ---
# mu: 4 it: 17 algorithms.label_propagation(G) 14
# mu: 4 it: 17 algorithms.leiden(G) 14
# mu: 4 it: 17 algorithms.significance_communities(G) 14
# mu: 4 it: 17 algorithms.surprise_communities(G) 14
# mu: 4 it: 17 algorithms.greedy_modularity(G) 14
# mu: 4 it: 17 algorithms.paris(G) 14
# mu: 4 it: 17 algorithms.louvain(G,resolution=0.75,randomize=314159) 14
# mu: 4 it: 17 algorithms.louvain(G,resolution=0.75,randomize=2718) 14
# mu: 4 it: 17 algorithms.louvain(G,resolution=1.0,randomize=314159) 14
# mu: 4 it: 17 algorithms.louvain(G,resolution=1.0,randomize=2718) 14
# mu: 4 it: 17 algorithms.louvain(G,resolution=1.25,randomize=314159) 14
# mu: 4 it: 17 algorithms.louvain(G,resolution=1.25,randomize=2718) 14
# mu: 4 it: 17 algorithms.louvain(G,resolution=1.5,randomize=314159) 14
# mu: 4 it: 17 algorithms.louvain(G,resolution=1.5,randomize=2718) 14
# mu: 4 it: 17 algorithms.infomap(G) 14
# mu: 4 it: 17 algorithms.walktrap(G) 14
# mu: 4 it: 17 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 4 it: 17 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 4 it: 17 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 4 it: 17 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 4 it: 17 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.01,convergence_check_frequency=100) 16
# mu: 4 it: 17 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.001,convergence_check_frequency=100) 16
# mu: 4 it: 17 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.01,convergence_check_frequency=100) 16
# mu: 4 it: 17 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.001,convergence_check_frequency=100) 16
# mu: 4 it: 17 algorithms.em(G,k=11) 9
# mu: 4 it: 17 algorithms.em(G,k=41) 8
# mu: 4 it: 17 algorithms.em(G,k=40) 10
# mu: 4 it: 17 algorithms.em(G,k=12) 9
# mu: 4 it: 17 algorithms.sbm_dl(G) 10
# UNSUCCESSFUL algorithms.spinglass(G,spins=11)
# UNSUCCESSFUL algorithms.spinglass(G,spins=41)
# UNSUCCESSFUL algorithms.spinglass(G,spins=40)
# UNSUCCESSFUL algorithms.spinglass(G,spins=12)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.3)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.5)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.6)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.75)
# mu: 4 it: 17 norm: 50.53711507397311
# ---
# mu: 4 it: 18 algorithms.label_propagation(G) 14
# mu: 4 it: 18 algorithms.leiden(G) 14
# mu: 4 it: 18 algorithms.significance_communities(G) 14
# mu: 4 it: 18 algorithms.surprise_communities(G) 14
# mu: 4 it: 18 algorithms.greedy_modularity(G) 14
# mu: 4 it: 18 algorithms.paris(G) 14
# mu: 4 it: 18 algorithms.louvain(G,resolution=0.75,randomize=314159) 14
# mu: 4 it: 18 algorithms.louvain(G,resolution=0.75,randomize=2718) 14
# mu: 4 it: 18 algorithms.louvain(G,resolution=1.0,randomize=314159) 14
# mu: 4 it: 18 algorithms.louvain(G,resolution=1.0,randomize=2718) 14
# mu: 4 it: 18 algorithms.louvain(G,resolution=1.25,randomize=314159) 14
# mu: 4 it: 18 algorithms.louvain(G,resolution=1.25,randomize=2718) 14
# mu: 4 it: 18 algorithms.louvain(G,resolution=1.5,randomize=314159) 14
# mu: 4 it: 18 algorithms.louvain(G,resolution=1.5,randomize=2718) 14
# mu: 4 it: 18 algorithms.infomap(G) 14
# mu: 4 it: 18 algorithms.walktrap(G) 14
# mu: 4 it: 18 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 4 it: 18 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 4 it: 18 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 4 it: 18 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 4 it: 18 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.01,convergence_check_frequency=100) 16
# mu: 4 it: 18 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.001,convergence_check_frequency=100) 16
# mu: 4 it: 18 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.01,convergence_check_frequency=100) 16
# mu: 4 it: 18 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.001,convergence_check_frequency=100) 16
# mu: 4 it: 18 algorithms.em(G,k=11) 5
# mu: 4 it: 18 algorithms.em(G,k=41) 8
# mu: 4 it: 18 algorithms.em(G,k=40) 12
# mu: 4 it: 18 algorithms.em(G,k=12) 6
# mu: 4 it: 18 algorithms.sbm_dl(G) 11
# UNSUCCESSFUL algorithms.spinglass(G,spins=11)
# UNSUCCESSFUL algorithms.spinglass(G,spins=41)
# UNSUCCESSFUL algorithms.spinglass(G,spins=40)
# UNSUCCESSFUL algorithms.spinglass(G,spins=12)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.3)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.5)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.6)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.75)
# mu: 4 it: 18 norm: 50.49752469181039
# ---
# mu: 4 it: 19 algorithms.label_propagation(G) 14
# mu: 4 it: 19 algorithms.leiden(G) 14
# mu: 4 it: 19 algorithms.significance_communities(G) 14
# mu: 4 it: 19 algorithms.surprise_communities(G) 14
# mu: 4 it: 19 algorithms.greedy_modularity(G) 14
# mu: 4 it: 19 algorithms.paris(G) 14
# mu: 4 it: 19 algorithms.louvain(G,resolution=0.75,randomize=314159) 14
# mu: 4 it: 19 algorithms.louvain(G,resolution=0.75,randomize=2718) 14
# mu: 4 it: 19 algorithms.louvain(G,resolution=1.0,randomize=314159) 14
# mu: 4 it: 19 algorithms.louvain(G,resolution=1.0,randomize=2718) 14
# mu: 4 it: 19 algorithms.louvain(G,resolution=1.25,randomize=314159) 14
# mu: 4 it: 19 algorithms.louvain(G,resolution=1.25,randomize=2718) 14
# mu: 4 it: 19 algorithms.louvain(G,resolution=1.5,randomize=314159) 14
# mu: 4 it: 19 algorithms.louvain(G,resolution=1.5,randomize=2718) 14
# mu: 4 it: 19 algorithms.infomap(G) 14
# mu: 4 it: 19 algorithms.walktrap(G) 14
# mu: 4 it: 19 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 4 it: 19 algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 4 it: 19 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 4 it: 19 algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 4 it: 19 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.01,convergence_check_frequency=100) 15
# mu: 4 it: 19 algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.001,convergence_check_frequency=100) 15
# mu: 4 it: 19 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.01,convergence_check_frequency=100) 16
# mu: 4 it: 19 algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.001,convergence_check_frequency=100) 16
# mu: 4 it: 19 algorithms.em(G,k=11) 8
# mu: 4 it: 19 algorithms.em(G,k=41) 9
# mu: 4 it: 19 algorithms.em(G,k=40) 11
# mu: 4 it: 19 algorithms.em(G,k=12) 6
# mu: 4 it: 19 algorithms.sbm_dl(G) 11
# UNSUCCESSFUL algorithms.spinglass(G,spins=11)
# UNSUCCESSFUL algorithms.spinglass(G,spins=41)
# UNSUCCESSFUL algorithms.spinglass(G,spins=40)
# UNSUCCESSFUL algorithms.spinglass(G,spins=12)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.3)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.5)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.6)
# UNSUCCESSFUL algorithms.ricci_community(G,alpha=0.75)
# mu: 4 it: 19 norm: 46.54030511288038
# ---

# %% [markdown]
# # n=1000

# %%
n = 1000
expected_clusters = []
for i in range(4):
    expected_clusters.append(random.randint(int(n ** (1. / 3)),3*int(n ** (1. / 2))))
    
alg_params = {
    "label_propagation": None,
    "leiden": None,
    "significance_communities": None,
    "surprise_communities": None,
    "greedy_modularity": None,
    "paris": None,
    "louvain": {
        "resolution": [0.75, 1.0, 1.25, 1.5],
        "randomize": [314159, 2718]
    },
    "infomap": None,
    "walktrap": None,
    "markov_clustering": {
        "inflation": [1.2, 1.5, 2, 2.5],
        "pruning_threshold": [0.01, 0.001],
        "convergence_check_frequency": [100]
    },
    "em": {
        "k": list(expected_clusters)
    },
    "sbm_dl": None,
    "spinglass": {
        "spins": list(expected_clusters)
    },
    "ricci_community": {
        "alpha": [0.3, 0.5, 0.6, 0.75]
    }
}

clustering_enumeration = []
count = 0
for alg, params in alg_params.items():
    param_combinations = []
    param_names = []
    if params is not None:
        iterables = []
        param_names = []
        for param in params.keys():
            iterables.append(list(params[param]))
            param_names.append(param)
        param_combinations = list(itertools.product(*iterables))
    if len(param_combinations) > 0:
        for param_combination in param_combinations:
            expr = "algorithms."+alg+"(G"
            for i in range(len(param_names)):
                expr = expr + "," + param_names[i] + "=" + str(param_combination[i])
            expr = expr + ")"
            clustering_enumeration.append((expr,count))
            count = count + 1      
    else:
        expr = "algorithms."+alg+"(G)"
        clustering_enumeration.append((expr,count))
        count = count + 1
        
print(clustering_enumeration)
# Out:
# [('algorithms.label_propagation(G)', 0), ('algorithms.leiden(G)', 1), ('algorithms.significance_communities(G)', 2), ('algorithms.surprise_communities(G)', 3), ('algorithms.greedy_modularity(G)', 4), ('algorithms.paris(G)', 5), ('algorithms.louvain(G,resolution=0.75,randomize=314159)', 6), ('algorithms.louvain(G,resolution=0.75,randomize=2718)', 7), ('algorithms.louvain(G,resolution=1.0,randomize=314159)', 8), ('algorithms.louvain(G,resolution=1.0,randomize=2718)', 9), ('algorithms.louvain(G,resolution=1.25,randomize=314159)', 10), ('algorithms.louvain(G,resolution=1.25,randomize=2718)', 11), ('algorithms.louvain(G,resolution=1.5,randomize=314159)', 12), ('algorithms.louvain(G,resolution=1.5,randomize=2718)', 13), ('algorithms.infomap(G)', 14), ('algorithms.walktrap(G)', 15), ('algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.01,convergence_check_frequency=100)', 16), ('algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.001,convergence_check_frequency=100)', 17), ('algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.01,convergence_check_frequency=100)', 18), ('algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.001,convergence_check_frequency=100)', 19), ('algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.01,convergence_check_frequency=100)', 20), ('algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.001,convergence_check_frequency=100)', 21), ('algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.01,convergence_check_frequency=100)', 22), ('algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.001,convergence_check_frequency=100)', 23), ('algorithms.em(G,k=59)', 24), ('algorithms.em(G,k=54)', 25), ('algorithms.em(G,k=66)', 26), ('algorithms.em(G,k=17)', 27), ('algorithms.sbm_dl(G)', 28), ('algorithms.spinglass(G,spins=59)', 29), ('algorithms.spinglass(G,spins=54)', 30), ('algorithms.spinglass(G,spins=66)', 31), ('algorithms.spinglass(G,spins=17)', 32), ('algorithms.ricci_community(G,alpha=0.3)', 33), ('algorithms.ricci_community(G,alpha=0.5)', 34), ('algorithms.ricci_community(G,alpha=0.6)', 35), ('algorithms.ricci_community(G,alpha=0.75)', 36)]

# %% [markdown]
# # n=5000

# %%
n = 5000
expected_clusters = []
for i in range(4):
    expected_clusters.append(random.randint(int(n ** (1. / 3)),3*int(n ** (1. / 2))))
    
alg_params = {
    "label_propagation": None,
    "leiden": None,
    "significance_communities": None,
    "surprise_communities": None,
    "greedy_modularity": None,
    "paris": None,
    "louvain": {
        "resolution": [0.75, 1.0, 1.25, 1.5],
        "randomize": [314159, 2718]
    },
    "infomap": None,
    "walktrap": None,
    "markov_clustering": {
        "inflation": [1.2, 1.5, 2, 2.5],
        "pruning_threshold": [0.01, 0.001],
        "convergence_check_frequency": [100]
    },
    "em": {
        "k": list(expected_clusters)
    },
    "sbm_dl": None,
    "spinglass": {
        "spins": list(expected_clusters)
    },
    "ricci_community": {
        "alpha": [0.3, 0.5, 0.6, 0.75]
    }
}

clustering_enumeration = []
count = 0
for alg, params in alg_params.items():
    param_combinations = []
    param_names = []
    if params is not None:
        iterables = []
        param_names = []
        for param in params.keys():
            iterables.append(list(params[param]))
            param_names.append(param)
        param_combinations = list(itertools.product(*iterables))
    if len(param_combinations) > 0:
        for param_combination in param_combinations:
            expr = "algorithms."+alg+"(G"
            for i in range(len(param_names)):
                expr = expr + "," + param_names[i] + "=" + str(param_combination[i])
            expr = expr + ")"
            clustering_enumeration.append((expr,count))
            count = count + 1      
    else:
        expr = "algorithms."+alg+"(G)"
        clustering_enumeration.append((expr,count))
        count = count + 1
        
print(clustering_enumeration)
# Out:
# [('algorithms.label_propagation(G)', 0), ('algorithms.leiden(G)', 1), ('algorithms.significance_communities(G)', 2), ('algorithms.surprise_communities(G)', 3), ('algorithms.greedy_modularity(G)', 4), ('algorithms.paris(G)', 5), ('algorithms.louvain(G,resolution=0.75,randomize=314159)', 6), ('algorithms.louvain(G,resolution=0.75,randomize=2718)', 7), ('algorithms.louvain(G,resolution=1.0,randomize=314159)', 8), ('algorithms.louvain(G,resolution=1.0,randomize=2718)', 9), ('algorithms.louvain(G,resolution=1.25,randomize=314159)', 10), ('algorithms.louvain(G,resolution=1.25,randomize=2718)', 11), ('algorithms.louvain(G,resolution=1.5,randomize=314159)', 12), ('algorithms.louvain(G,resolution=1.5,randomize=2718)', 13), ('algorithms.infomap(G)', 14), ('algorithms.walktrap(G)', 15), ('algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.01,convergence_check_frequency=100)', 16), ('algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.001,convergence_check_frequency=100)', 17), ('algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.01,convergence_check_frequency=100)', 18), ('algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.001,convergence_check_frequency=100)', 19), ('algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.01,convergence_check_frequency=100)', 20), ('algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.001,convergence_check_frequency=100)', 21), ('algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.01,convergence_check_frequency=100)', 22), ('algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.001,convergence_check_frequency=100)', 23), ('algorithms.em(G,k=168)', 24), ('algorithms.em(G,k=168)', 25), ('algorithms.em(G,k=40)', 26), ('algorithms.em(G,k=207)', 27), ('algorithms.sbm_dl(G)', 28), ('algorithms.spinglass(G,spins=168)', 29), ('algorithms.spinglass(G,spins=168)', 30), ('algorithms.spinglass(G,spins=40)', 31), ('algorithms.spinglass(G,spins=207)', 32), ('algorithms.ricci_community(G,alpha=0.3)', 33), ('algorithms.ricci_community(G,alpha=0.5)', 34), ('algorithms.ricci_community(G,alpha=0.6)', 35), ('algorithms.ricci_community(G,alpha=0.75)', 36)]
