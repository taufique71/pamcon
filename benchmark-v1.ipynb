# %%
import networkx as nx
import networkx.algorithms.community as nx_comm
from networkx.generators.community import LFR_benchmark_graph
from networkx.algorithms import bipartite
import numpy as np
import scipy as sp
from scipy.sparse import coo_array
from scipy import sparse
from cdlib import algorithms
from cdlib import evaluation
import sklearn
from utils import *
from distances import *
from consensus import *
import math
import itertools
import random
from pathlib import Path

# %%
cons_name = "v1"

# %%
def v1_consensus(P_list, niter=10, verbose=True):
    G = nx.Graph(P_list[0]["graph"])
    n = len(list(G.nodes()))
    k = len(P_list)
    #print("Number of nodes", n)
    
    row = []
    col = []
    val = []
    for x in P_list:
        graph = x["graph"]
        partition = x["partition"]
        for cluster in partition:
            for i in range(len(cluster)):
                for j in range(i+1, len(cluster)):
                    item_1 = cluster[i]
                    item_2 = cluster[j]
                    row.append(int(item_1))
                    col.append(int(item_2))
                    val.append(int(1))
                    
    r = coo_array((val, (row, col)), shape=(n, n))
    r = r.tocsr()
                
    refined_partition = None
    for x in P_list:
        graph = x["graph"]
        partition = x["partition"]
        if not refined_partition:
            refined_partition = list(partition)
        new_partition = []
        for clusterA in refined_partition:
            for clusterB in partition:
                seta = set(clusterA)
                setb = set(clusterB)
                anb = seta.intersection(setb)
                if len(anb) != 0:
                    new_partition.append(list(anb))
        refined_partition = list(new_partition)
    
    refined_partition_map = clust_lst_to_map(refined_partition)
    
    if verbose:
        print("Number of core clusters", len(refined_partition_map))
    
    items = list(refined_partition_map.keys())
    count = 0
    it = 0
    while(it < niter):
        random.shuffle(items)
        flag = True
        for item in items:
            neighbors = []
            if isinstance(items[0], int):
                neighbors = [n for n in G.neighbors(int(item))]
            else:
                neighbors = [str(n) for n in G.neighbors(int(item))]
                
            if len(neighbors) > 0:
                opt_diff = 0
                opt_src_clust_no = refined_partition_map[item]
                opt_dst_clust_no = refined_partition_map[item]

                diff_src = 0
                for elem in refined_partition[opt_src_clust_no]:
                    i = min(int(item), int(elem))
                    j = max(int(item), int(elem))
                    diff_src = diff_src + (k - 2*r[i,j])
                
                for neighbor in neighbors:
                    if refined_partition_map[neighbor] != opt_src_clust_no:
                        dst_clust_no = refined_partition_map[neighbor]
                        diff_dst = 0

                        for elem in refined_partition[dst_clust_no]:
                            i = min(int(item), int(elem))
                            j = max(int(item), int(elem))
                            diff_dst = diff_dst + (k - 2*r[i,j])

                        if diff_dst - diff_src < opt_diff:
                            opt_diff = diff_dst - diff_src
                            opt_dst_clust_no = dst_clust_no
                            
                if opt_src_clust_no != opt_dst_clust_no:
                    refined_partition[opt_src_clust_no].remove(item)
                    refined_partition[opt_dst_clust_no].append(item)
                    
                    refined_partition_map[item] = opt_src_clust_no
                    refined_partition_map[item] = opt_dst_clust_no
                    
                    flag = False
                    count = count + 1
                    if verbose:
                        print("Move:", count, "|",
                              "Moving", item, 
                              "from cluster", 
                              opt_src_clust_no, "( size", len(refined_partition[opt_src_clust_no])+1, ")", 
                              "to", 
                              opt_dst_clust_no, "( size", len(refined_partition[opt_dst_clust_no])-1, ")",
                              "distance reduction:", opt_diff
                             )
            else:
                # No move necessary
                pass
        if verbose:
            print("---", it, "/", niter, "---")
        if flag:
            break
        it = it + 1
    
    empty_clusters = []
    for i in range(len(refined_partition)):
        if len(refined_partition[i]) == 0:
            empty_clusters.append(i)
            
    empty_clusters.sort(reverse=True)
    for e in empty_clusters:
        del refined_partition[e]
    
    return {"graph": nx.Graph(G), "partition": list(refined_partition)}

# %% [markdown]
# ## Parameter configurations for clustering generation

# %%
n = 1000
expected_clusters = []
for i in range(4):
    expected_clusters.append(random.randint(int(n ** (1. / 3)),3*int(n ** (1. / 2))))
    
alg_params = {
    "label_propagation": None,
    "leiden": None,
    "significance_communities": None,
    "surprise_communities": None,
    "greedy_modularity": None,
    "paris": None,
    "louvain": {
        "resolution": [0.75, 1.0, 1.25, 1.5],
        "randomize": [314159, 2718]
    },
    "infomap": None,
    "walktrap": None,
    "markov_clustering": {
        "inflation": [1.2, 1.5, 2, 2.5],
        "pruning_threshold": [0.01, 0.001],
        "convergence_check_frequency": [100]
    },
    "em": {
        "k": list(expected_clusters)
    },
    "sbm_dl": None,
    "spinglass": {
        "spins": list(expected_clusters)
    },
    "ricci_community": {
        "alpha": [0.3, 0.5, 0.6, 0.75]
    }
}

# %% [markdown]
# ## Enumerate clusterings

# %%
clustering_enumeration = []
count = 0
for alg, params in alg_params.items():
    param_combinations = []
    param_names = []
    if params is not None:
        iterables = []
        param_names = []
        for param in params.keys():
            iterables.append(list(params[param]))
            param_names.append(param)
        param_combinations = list(itertools.product(*iterables))
    if len(param_combinations) > 0:
        for param_combination in param_combinations:
            expr = "algorithms."+alg+"(G"
            for i in range(len(param_names)):
                expr = expr + "," + param_names[i] + "=" + str(param_combination[i])
            expr = expr + ")"
            clustering_enumeration.append((expr,count))
            count = count + 1      
    else:
        expr = "algorithms."+alg+"(G)"
        clustering_enumeration.append((expr,count))
        count = count + 1
print(clustering_enumeration)
# Out:
# [('algorithms.label_propagation(G)', 0), ('algorithms.leiden(G)', 1), ('algorithms.significance_communities(G)', 2), ('algorithms.surprise_communities(G)', 3), ('algorithms.greedy_modularity(G)', 4), ('algorithms.paris(G)', 5), ('algorithms.louvain(G,resolution=0.75,randomize=314159)', 6), ('algorithms.louvain(G,resolution=0.75,randomize=2718)', 7), ('algorithms.louvain(G,resolution=1.0,randomize=314159)', 8), ('algorithms.louvain(G,resolution=1.0,randomize=2718)', 9), ('algorithms.louvain(G,resolution=1.25,randomize=314159)', 10), ('algorithms.louvain(G,resolution=1.25,randomize=2718)', 11), ('algorithms.louvain(G,resolution=1.5,randomize=314159)', 12), ('algorithms.louvain(G,resolution=1.5,randomize=2718)', 13), ('algorithms.infomap(G)', 14), ('algorithms.walktrap(G)', 15), ('algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.01,convergence_check_frequency=100)', 16), ('algorithms.markov_clustering(G,inflation=1.2,pruning_threshold=0.001,convergence_check_frequency=100)', 17), ('algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.01,convergence_check_frequency=100)', 18), ('algorithms.markov_clustering(G,inflation=1.5,pruning_threshold=0.001,convergence_check_frequency=100)', 19), ('algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.01,convergence_check_frequency=100)', 20), ('algorithms.markov_clustering(G,inflation=2,pruning_threshold=0.001,convergence_check_frequency=100)', 21), ('algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.01,convergence_check_frequency=100)', 22), ('algorithms.markov_clustering(G,inflation=2.5,pruning_threshold=0.001,convergence_check_frequency=100)', 23), ('algorithms.em(G,k=69)', 24), ('algorithms.em(G,k=60)', 25), ('algorithms.em(G,k=59)', 26), ('algorithms.em(G,k=74)', 27), ('algorithms.sbm_dl(G)', 28), ('algorithms.spinglass(G,spins=69)', 29), ('algorithms.spinglass(G,spins=60)', 30), ('algorithms.spinglass(G,spins=59)', 31), ('algorithms.spinglass(G,spins=74)', 32), ('algorithms.ricci_community(G,alpha=0.3)', 33), ('algorithms.ricci_community(G,alpha=0.5)', 34), ('algorithms.ricci_community(G,alpha=0.6)', 35), ('algorithms.ricci_community(G,alpha=0.75)', 36)]

# %%
import random

n = 1000
fileprefix = "LFR/" + "n" + str(n) + "/"
#mus = [1, 2, 3, 4]
mus = [4]
gammas = [30]
betas = [11]
for mu in mus:
    for gamma in gammas:
        for beta in betas:
            P_list = []
            fname = "LFR_n" + str(n) + "_mu0" + str(mu) + "_gamma" + str(gamma) + "_beta" + str(beta)
            graph_file = fileprefix + fname + ".mtx"
            G = None
            with open(graph_file) as f:
                G = nx.from_scipy_sparse_array(spio.mmread(f), create_using=nx.Graph)
                coms = None
                for k in clustering_enumeration:
                    clust_file = fileprefix + fname + "." + str(k[1])
                    if Path(clust_file).is_file():
                        partition = read_clust_lst(clust_file)
                        P_list.append({"graph": nx.Graph(G), "partition": list(partition)})
                P_star = v1_consensus(P_list, niter=20, verbose=True)
                print("mu", mu, ", number of clusters", len(P_star["partition"]))
                write_clust_lst(P_star["partition"], fileprefix + fname + "." + cons_name)
# Out:
# Number of core clusters 1000
# Move: 1 | Moving 363 from cluster 473 ( size 1 ) to 469 ( size 1 ) distance reduction: -58
# Move: 2 | Moving 473 from cluster 71 ( size 1 ) to 0 ( size 1 ) distance reduction: -48
# Move: 3 | Moving 611 from cluster 412 ( size 1 ) to 395 ( size 1 ) distance reduction: -56
# Move: 4 | Moving 945 from cluster 950 ( size 1 ) to 940 ( size 1 ) distance reduction: -56
# Move: 5 | Moving 814 from cluster 128 ( size 1 ) to 126 ( size 1 ) distance reduction: -60
# Move: 6 | Moving 536 from cluster 609 ( size 1 ) to 593 ( size 1 ) distance reduction: -54
# Move: 7 | Moving 108 from cluster 858 ( size 1 ) to 855 ( size 1 ) distance reduction: -62
# Move: 8 | Moving 713 from cluster 93 ( size 1 ) to 98 ( size 1 ) distance reduction: -58
# Move: 9 | Moving 599 from cluster 411 ( size 1 ) to 395 ( size 2 ) distance reduction: -54
# Move: 10 | Moving 608 from cluster 990 ( size 1 ) to 979 ( size 1 ) distance reduction: -58
# Move: 11 | Moving 260 from cluster 830 ( size 1 ) to 829 ( size 1 ) distance reduction: -58
# Move: 12 | Moving 463 from cluster 727 ( size 1 ) to 725 ( size 1 ) distance reduction: -58
# Move: 13 | Moving 672 from cluster 913 ( size 1 ) to 890 ( size 1 ) distance reduction: -60
# Move: 14 | Moving 419 from cluster 83 ( size 1 ) to 79 ( size 1 ) distance reduction: -56
# Move: 15 | Moving 539 from cluster 287 ( size 1 ) to 289 ( size 1 ) distance reduction: -62
# Move: 16 | Moving 36 from cluster 656 ( size 1 ) to 666 ( size 1 ) distance reduction: -62
# Move: 17 | Moving 595 from cluster 331 ( size 1 ) to 333 ( size 1 ) distance reduction: -62
# Move: 18 | Moving 135 from cluster 117 ( size 1 ) to 116 ( size 1 ) distance reduction: -54
# Move: 19 | Moving 342 from cluster 191 ( size 1 ) to 161 ( size 1 ) distance reduction: -48
# Move: 20 | Moving 164 from cluster 522 ( size 1 ) to 535 ( size 1 ) distance reduction: -60
# Move: 21 | Moving 481 from cluster 429 ( size 1 ) to 427 ( size 1 ) distance reduction: -58
# Move: 22 | Moving 882 from cluster 443 ( size 1 ) to 448 ( size 1 ) distance reduction: -54
# Move: 23 | Moving 115 from cluster 373 ( size 1 ) to 381 ( size 1 ) distance reduction: -56
# Move: 24 | Moving 223 from cluster 455 ( size 1 ) to 423 ( size 1 ) distance reduction: -58
# Move: 25 | Moving 221 from cluster 824 ( size 1 ) to 823 ( size 1 ) distance reduction: -58
# Move: 26 | Moving 601 from cluster 736 ( size 1 ) to 721 ( size 1 ) distance reduction: -56
# Move: 27 | Moving 65 from cluster 75 ( size 1 ) to 81 ( size 1 ) distance reduction: -54
# Move: 28 | Moving 937 from cluster 687 ( size 1 ) to 683 ( size 1 ) distance reduction: -60
# Move: 29 | Moving 393 from cluster 942 ( size 1 ) to 940 ( size 2 ) distance reduction: -70
# Move: 30 | Moving 815 from cluster 841 ( size 1 ) to 829 ( size 2 ) distance reduction: -68
# Move: 31 | Moving 415 from cluster 405 ( size 1 ) to 406 ( size 1 ) distance reduction: -44
# Move: 32 | Moving 852 from cluster 345 ( size 1 ) to 333 ( size 2 ) distance reduction: -62
# Move: 33 | Moving 708 from cluster 389 ( size 1 ) to 381 ( size 2 ) distance reduction: -76
# Move: 34 | Moving 233 from cluster 32 ( size 1 ) to 34 ( size 1 ) distance reduction: -64
# Move: 35 | Moving 556 from cluster 624 ( size 1 ) to 638 ( size 1 ) distance reduction: -58
# Move: 36 | Moving 84 from cluster 891 ( size 1 ) to 890 ( size 2 ) distance reduction: -66
# Move: 37 | Moving 56 from cluster 698 ( size 1 ) to 721 ( size 2 ) distance reduction: -74
# Move: 38 | Moving 277 from cluster 1 ( size 1 ) to 7 ( size 1 ) distance reduction: -56
# Move: 39 | Moving 347 from cluster 920 ( size 1 ) to 918 ( size 1 ) distance reduction: -34
# Move: 40 | Moving 607 from cluster 801 ( size 1 ) to 813 ( size 1 ) distance reduction: -58
# Move: 41 | Moving 11 from cluster 818 ( size 1 ) to 829 ( size 3 ) distance reduction: -88
# Move: 42 | Moving 767 from cluster 879 ( size 1 ) to 862 ( size 1 ) distance reduction: -60
# Move: 43 | Moving 563 from cluster 157 ( size 1 ) to 161 ( size 2 ) distance reduction: -62
# Move: 44 | Moving 792 from cluster 9 ( size 1 ) to 7 ( size 2 ) distance reduction: -72
# Move: 45 | Moving 934 from cluster 445 ( size 1 ) to 448 ( size 2 ) distance reduction: -74
# Move: 46 | Moving 61 from cluster 956 ( size 1 ) to 961 ( size 1 ) distance reduction: -56
# Move: 47 | Moving 848 from cluster 344 ( size 1 ) to 333 ( size 3 ) distance reduction: -84
# Move: 48 | Moving 136 from cluster 142 ( size 1 ) to 161 ( size 3 ) distance reduction: -94
# Move: 49 | Moving 452 from cluster 428 ( size 1 ) to 448 ( size 3 ) distance reduction: -90
# Move: 50 | Moving 95 from cluster 193 ( size 1 ) to 189 ( size 1 ) distance reduction: -50
# Move: 51 | Moving 205 from cluster 143 ( size 1 ) to 161 ( size 4 ) distance reduction: -108
# Move: 52 | Moving 146 from cluster 895 ( size 1 ) to 890 ( size 3 ) distance reduction: -86
# Move: 53 | Moving 470 from cluster 651 ( size 1 ) to 650 ( size 1 ) distance reduction: -54
# Move: 54 | Moving 427 from cluster 943 ( size 1 ) to 940 ( size 3 ) distance reduction: -102
# Move: 55 | Moving 519 from cluster 620 ( size 1 ) to 634 ( size 1 ) distance reduction: -54
# Move: 56 | Moving 66 from cluster 699 ( size 1 ) to 721 ( size 3 ) distance reduction: -94
# Move: 57 | Moving 354 from cluster 382 ( size 1 ) to 376 ( size 1 ) distance reduction: -62
# Move: 58 | Moving 526 from cluster 757 ( size 1 ) to 759 ( size 1 ) distance reduction: -60
# Move: 59 | Moving 123 from cluster 894 ( size 1 ) to 890 ( size 4 ) distance reduction: -110
# Move: 60 | Moving 86 from cluster 364 ( size 1 ) to 362 ( size 1 ) distance reduction: -52
# Move: 61 | Moving 208 from cluster 299 ( size 1 ) to 264 ( size 1 ) distance reduction: -54
# Move: 62 | Moving 930 from cluster 502 ( size 1 ) to 503 ( size 1 ) distance reduction: -58
# Move: 63 | Moving 261 from cluster 79 ( size 2 ) to 98 ( size 2 ) distance reduction: -54
# Move: 64 | Moving 769 from cluster 390 ( size 1 ) to 381 ( size 3 ) distance reduction: -96
# Move: 65 | Moving 873 from cluster 812 ( size 1 ) to 786 ( size 1 ) distance reduction: -58
# Move: 66 | Moving 77 from cluster 140 ( size 1 ) to 161 ( size 5 ) distance reduction: -128
# Move: 67 | Moving 41 from cluster 980 ( size 1 ) to 981 ( size 1 ) distance reduction: -60
# Move: 68 | Moving 851 from cluster 762 ( size 1 ) to 754 ( size 1 ) distance reduction: -60
# Move: 69 | Moving 214 from cluster 144 ( size 1 ) to 161 ( size 6 ) distance reduction: -158
# Move: 70 | Moving 615 from cluster 238 ( size 1 ) to 233 ( size 1 ) distance reduction: -56
# Move: 71 | Moving 979 from cluster 449 ( size 1 ) to 448 ( size 4 ) distance reduction: -118
# Move: 72 | Moving 730 from cluster 162 ( size 1 ) to 161 ( size 7 ) distance reduction: -188
# Move: 73 | Moving 734 from cluster 484 ( size 1 ) to 486 ( size 1 ) distance reduction: -58
# Move: 74 | Moving 359 from cluster 901 ( size 1 ) to 890 ( size 5 ) distance reduction: -134
# Move: 75 | Moving 908 from cluster 640 ( size 1 ) to 641 ( size 1 ) distance reduction: -62
# Move: 76 | Moving 567 from cluster 710 ( size 1 ) to 721 ( size 4 ) distance reduction: -108
# Move: 77 | Moving 105 from cluster 62 ( size 1 ) to 63 ( size 1 ) distance reduction: -50
# Move: 78 | Moving 777 from cluster 839 ( size 1 ) to 829 ( size 4 ) distance reduction: -102
# Move: 79 | Moving 383 from cluster 409 ( size 1 ) to 374 ( size 1 ) distance reduction: -56
# Move: 80 | Moving 535 from cluster 989 ( size 1 ) to 979 ( size 2 ) distance reduction: -68
# Move: 81 | Moving 128 from cluster 15 ( size 1 ) to 19 ( size 1 ) distance reduction: -60
# Move: 82 | Moving 448 from cluster 309 ( size 1 ) to 301 ( size 1 ) distance reduction: -56
# Move: 83 | Moving 292 from cluster 899 ( size 1 ) to 890 ( size 6 ) distance reduction: -154
# Move: 84 | Moving 8 from cluster 418 ( size 1 ) to 448 ( size 5 ) distance reduction: -128
# Move: 85 | Moving 596 from cluster 799 ( size 1 ) to 788 ( size 1 ) distance reduction: -58
# Move: 86 | Moving 124 from cluster 30 ( size 1 ) to 40 ( size 1 ) distance reduction: -52
# Move: 87 | Moving 200 from cluster 525 ( size 1 ) to 551 ( size 1 ) distance reduction: -58
# Move: 88 | Moving 418 from cluster 153 ( size 1 ) to 161 ( size 8 ) distance reduction: -150
# Move: 89 | Moving 959 from cluster 847 ( size 1 ) to 836 ( size 1 ) distance reduction: -60
# Move: 90 | Moving 279 from cluster 596 ( size 1 ) to 593 ( size 2 ) distance reduction: -76
# Move: 91 | Moving 117 from cluster 567 ( size 1 ) to 574 ( size 1 ) distance reduction: -58
# Move: 92 | Moving 969 from cluster 170 ( size 1 ) to 161 ( size 9 ) distance reduction: -218
# Move: 93 | Moving 791 from cluster 220 ( size 1 ) to 205 ( size 1 ) distance reduction: -56
# Move: 94 | Moving 289 from cluster 300 ( size 1 ) to 295 ( size 1 ) distance reduction: -44
# Move: 95 | Moving 693 from cluster 92 ( size 1 ) to 98 ( size 3 ) distance reduction: -94
# Move: 96 | Moving 492 from cluster 410 ( size 1 ) to 738 ( size 1 ) distance reduction: -34
# Move: 97 | Moving 665 from cluster 993 ( size 1 ) to 979 ( size 3 ) distance reduction: -92
# Move: 98 | Moving 886 from cluster 39 ( size 1 ) to 34 ( size 2 ) distance reduction: -74
# Move: 99 | Moving 861 from cluster 843 ( size 1 ) to 829 ( size 5 ) distance reduction: -134
# Move: 100 | Moving 669 from cluster 36 ( size 1 ) to 34 ( size 3 ) distance reduction: -88
# Move: 101 | Moving 271 from cluster 402 ( size 1 ) to 381 ( size 4 ) distance reduction: -110
# Move: 102 | Moving 395 from cluster 706 ( size 1 ) to 721 ( size 5 ) distance reduction: -106
# Move: 103 | Moving 70 from cluster 139 ( size 1 ) to 161 ( size 10 ) distance reduction: -244
# Move: 104 | Moving 31 from cluster 504 ( size 1 ) to 471 ( size 1 ) distance reduction: -36
# Move: 105 | Moving 439 from cluster 509 ( size 1 ) to 505 ( size 1 ) distance reduction: -38
# Move: 106 | Moving 645 from cluster 911 ( size 1 ) to 890 ( size 7 ) distance reduction: -172
# Move: 107 | Moving 893 from cluster 223 ( size 1 ) to 221 ( size 1 ) distance reduction: -60
# Move: 108 | Moving 689 from cluster 414 ( size 1 ) to 413 ( size 1 ) distance reduction: -52
# Move: 109 | Moving 906 from cluster 557 ( size 1 ) to 535 ( size 2 ) distance reduction: -78
# Move: 110 | Moving 57 from cluster 103 ( size 1 ) to 101 ( size 1 ) distance reduction: -58
# Move: 111 | Moving 836 from cluster 190 ( size 1 ) to 187 ( size 1 ) distance reduction: -50
# Move: 112 | Moving 144 from cluster 374 ( size 2 ) to 381 ( size 5 ) distance reduction: -126
# Move: 113 | Moving 664 from cluster 355 ( size 1 ) to 359 ( size 1 ) distance reduction: -54
# Move: 114 | Moving 331 from cluster 112 ( size 1 ) to 111 ( size 1 ) distance reduction: -56
# Move: 115 | Moving 362 from cluster 866 ( size 1 ) to 862 ( size 2 ) distance reduction: -72
# Move: 116 | Moving 37 from cluster 857 ( size 1 ) to 862 ( size 3 ) distance reduction: -92
# Move: 117 | Moving 622 from cluster 875 ( size 1 ) to 862 ( size 4 ) distance reduction: -120
# Move: 118 | Moving 976 from cluster 561 ( size 1 ) to 535 ( size 3 ) distance reduction: -84
# Move: 119 | Moving 384 from cluster 985 ( size 1 ) to 979 ( size 4 ) distance reduction: -112
# Move: 120 | Moving 178 from cluster 174 ( size 1 ) to 173 ( size 1 ) distance reduction: -60
# Move: 121 | Moving 143 from cluster 31 ( size 1 ) to 34 ( size 4 ) distance reduction: -94
# Move: 122 | Moving 825 from cluster 272 ( size 1 ) to 264 ( size 2 ) distance reduction: -66
# Move: 123 | Moving 855 from cluster 811 ( size 1 ) to 788 ( size 2 ) distance reduction: -76
# Move: 124 | Moving 262 from cluster 530 ( size 1 ) to 535 ( size 4 ) distance reduction: -104
# Move: 125 | Moving 192 from cluster 595 ( size 1 ) to 593 ( size 3 ) distance reduction: -94
# Move: 126 | Moving 919 from cluster 972 ( size 1 ) to 961 ( size 2 ) distance reduction: -68
# Move: 127 | Moving 154 from cluster 57 ( size 1 ) to 59 ( size 1 ) distance reduction: -40
# Move: 128 | Moving 291 from cluster 324 ( size 1 ) to 333 ( size 4 ) distance reduction: -112
# Move: 129 | Moving 410 from cluster 104 ( size 1 ) to 101 ( size 2 ) distance reduction: -82
# Move: 130 | Moving 378 from cluster 210 ( size 1 ) to 203 ( size 1 ) distance reduction: -62
# Move: 131 | Moving 785 from cluster 840 ( size 1 ) to 829 ( size 6 ) distance reduction: -146
# Move: 132 | Moving 876 from cluster 844 ( size 1 ) to 829 ( size 7 ) distance reduction: -168
# Move: 133 | Moving 475 from cluster 731 ( size 1 ) to 701 ( size 1 ) distance reduction: -58
# Move: 134 | Moving 701 from cluster 463 ( size 1 ) to 464 ( size 1 ) distance reduction: -54
# Move: 135 | Moving 147 from cluster 394 ( size 1 ) to 395 ( size 3 ) distance reduction: -78
# Move: 136 | Moving 337 from cluster 865 ( size 1 ) to 862 ( size 5 ) distance reduction: -146
# Move: 137 | Moving 661 from cluster 671 ( size 1 ) to 666 ( size 2 ) distance reduction: -76
# Move: 138 | Moving 916 from cluster 558 ( size 1 ) to 551 ( size 2 ) distance reduction: -76
# Move: 139 | Moving 582 from cluster 952 ( size 1 ) to 925 ( size 1 ) distance reduction: -50
# Move: 140 | Moving 780 from cluster 807 ( size 1 ) to 788 ( size 3 ) distance reduction: -94
# Move: 141 | Moving 353 from cluster 647 ( size 1 ) to 646 ( size 1 ) distance reduction: -46
# Move: 142 | Moving 796 from cluster 291 ( size 1 ) to 289 ( size 2 ) distance reduction: -74
# Move: 143 | Moving 317 from cluster 177 ( size 1 ) to 173 ( size 2 ) distance reduction: -82
# Move: 144 | Moving 435 from cluster 427 ( size 2 ) to 446 ( size 1 ) distance reduction: -40
# Move: 145 | Moving 809 from cluster 10 ( size 1 ) to 7 ( size 3 ) distance reduction: -98
# Move: 146 | Moving 13 from cluster 516 ( size 1 ) to 535 ( size 5 ) distance reduction: -126
# Move: 147 | Moving 225 from cluster 527 ( size 1 ) to 535 ( size 6 ) distance reduction: -140
# Move: 148 | Moving 323 from cluster 927 ( size 1 ) to 935 ( size 1 ) distance reduction: -54
# Move: 149 | Moving 824 from cluster 695 ( size 1 ) to 666 ( size 3 ) distance reduction: -80
# Move: 150 | Moving 584 from cluster 964 ( size 1 ) to 961 ( size 3 ) distance reduction: -88
# Move: 151 | Moving 211 from cluster 422 ( size 1 ) to 448 ( size 6 ) distance reduction: -120
# Move: 152 | Moving 102 from cluster 172 ( size 1 ) to 173 ( size 3 ) distance reduction: -106
# Move: 153 | Moving 163 from cluster 200 ( size 1 ) to 273 ( size 1 ) distance reduction: -30
# Move: 154 | Moving 764 from cluster 773 ( size 1 ) to 741 ( size 1 ) distance reduction: -56
# Move: 155 | Moving 203 from cluster 679 ( size 1 ) to 683 ( size 2 ) distance reduction: -80
# Move: 156 | Moving 87 from cluster 141 ( size 1 ) to 161 ( size 11 ) distance reduction: -228
# Move: 157 | Moving 530 from cluster 622 ( size 1 ) to 638 ( size 2 ) distance reduction: -80
# Move: 158 | Moving 580 from cluster 963 ( size 1 ) to 961 ( size 4 ) distance reduction: -118
# Move: 159 | Moving 711 from cluster 338 ( size 1 ) to 333 ( size 5 ) distance reduction: -132
# Move: 160 | Moving 846 from cluster 555 ( size 1 ) to 535 ( size 7 ) distance reduction: -154
# Move: 161 | Moving 10 from cluster 655 ( size 1 ) to 666 ( size 4 ) distance reduction: -114
# Move: 162 | Moving 130 from cluster 116 ( size 2 ) to 118 ( size 1 ) distance reduction: -42
# Move: 163 | Moving 531 from cluster 156 ( size 1 ) to 163 ( size 1 ) distance reduction: -56
# Move: 164 | Moving 195 from cluster 118 ( size 2 ) to 116 ( size 1 ) distance reduction: -30
# Move: 165 | Moving 437 from cluster 777 ( size 1 ) to 740 ( size 1 ) distance reduction: -56
# Move: 166 | Moving 491 from cluster 728 ( size 1 ) to 721 ( size 6 ) distance reduction: -120
# Move: 167 | Moving 955 from cluster 814 ( size 1 ) to 813 ( size 2 ) distance reduction: -70
# Move: 168 | Moving 727 from cluster 457 ( size 1 ) to 421 ( size 1 ) distance reduction: -38
# Move: 169 | Moving 388 from cluster 211 ( size 1 ) to 205 ( size 2 ) distance reduction: -74
# Move: 170 | Moving 468 from cluster 872 ( size 1 ) to 862 ( size 6 ) distance reduction: -172
# Move: 171 | Moving 869 from cluster 138 ( size 1 ) to 98 ( size 4 ) distance reduction: -110
# Move: 172 | Moving 239 from cluster 827 ( size 1 ) to 829 ( size 8 ) distance reduction: -192
# Move: 173 | Moving 141 from cluster 470 ( size 1 ) to 476 ( size 1 ) distance reduction: -56
# Move: 174 | Moving 397 from cluster 725 ( size 2 ) to 726 ( size 1 ) distance reduction: -38
# Move: 175 | Moving 732 from cluster 738 ( size 2 ) to 726 ( size 2 ) distance reduction: -72
# Move: 176 | Moving 387 from cluster 152 ( size 1 ) to 161 ( size 12 ) distance reduction: -278
# Move: 177 | Moving 847 from cluster 501 ( size 1 ) to 500 ( size 1 ) distance reduction: -58
# Move: 178 | Moving 252 from cluster 423 ( size 2 ) to 448 ( size 7 ) distance reduction: -138
# Move: 179 | Moving 64 from cluster 370 ( size 1 ) to 381 ( size 6 ) distance reduction: -158
# Move: 180 | Moving 272 from cluster 532 ( size 1 ) to 551 ( size 3 ) distance reduction: -102
# Move: 181 | Moving 471 from cluster 905 ( size 1 ) to 890 ( size 8 ) distance reduction: -188
# Move: 182 | Moving 904 from cluster 248 ( size 1 ) to 229 ( size 1 ) distance reduction: -60
# Move: 183 | Moving 828 from cluster 163 ( size 2 ) to 161 ( size 13 ) distance reduction: -274
# Move: 184 | Moving 703 from cluster 184 ( size 1 ) to 173 ( size 4 ) distance reduction: -124
# Move: 185 | Moving 676 from cluster 578 ( size 1 ) to 574 ( size 2 ) distance reduction: -78
# Move: 186 | Moving 298 from cluster 466 ( size 1 ) to 448 ( size 8 ) distance reduction: -160
# Move: 187 | Moving 462 from cluster 315 ( size 1 ) to 314 ( size 1 ) distance reduction: -54
# Move: 188 | Moving 990 from cluster 252 ( size 1 ) to 251 ( size 1 ) distance reduction: -54
# Move: 189 | Moving 694 from cluster 182 ( size 1 ) to 173 ( size 5 ) distance reduction: -148
# Move: 190 | Moving 308 from cluster 120 ( size 1 ) to 98 ( size 5 ) distance reduction: -134
# Move: 191 | Moving 503 from cluster 329 ( size 1 ) to 333 ( size 6 ) distance reduction: -146
# Move: 192 | Moving 332 from cluster 326 ( size 1 ) to 333 ( size 7 ) distance reduction: -180
# Move: 193 | Moving 677 from cluster 413 ( size 2 ) to 381 ( size 7 ) distance reduction: -120
# Move: 194 | Moving 338 from cluster 3 ( size 1 ) to 7 ( size 4 ) distance reduction: -104
# Move: 195 | Moving 438 from cluster 793 ( size 1 ) to 788 ( size 4 ) distance reduction: -92
# Move: 196 | Moving 700 from cluster 549 ( size 1 ) to 535 ( size 8 ) distance reduction: -186
# Move: 197 | Moving 487 from cluster 189 ( size 2 ) to 188 ( size 1 ) distance reduction: -36
# Move: 198 | Moving 52 from cluster 955 ( size 1 ) to 973 ( size 1 ) distance reduction: -58
# Move: 199 | Moving 521 from cluster 621 ( size 1 ) to 638 ( size 3 ) distance reduction: -86
# Move: 200 | Moving 657 from cluster 367 ( size 1 ) to 333 ( size 8 ) distance reduction: -164
# Move: 201 | Moving 98 from cluster 229 ( size 2 ) to 233 ( size 2 ) distance reduction: -52
# Move: 202 | Moving 350 from cluster 833 ( size 1 ) to 829 ( size 9 ) distance reduction: -194
# Move: 203 | Moving 752 from cluster 219 ( size 1 ) to 205 ( size 3 ) distance reduction: -74
# Move: 204 | Moving 429 from cluster 680 ( size 1 ) to 688 ( size 1 ) distance reduction: -58
# Move: 205 | Moving 527 from cluster 386 ( size 1 ) to 381 ( size 8 ) distance reduction: -152
# Move: 206 | Moving 726 from cluster 776 ( size 1 ) to 775 ( size 1 ) distance reduction: -56
# Move: 207 | Moving 198 from cluster 260 ( size 1 ) to 264 ( size 3 ) distance reduction: -82
# Move: 208 | Moving 801 from cluster 584 ( size 1 ) to 574 ( size 3 ) distance reduction: -94
# Move: 209 | Moving 983 from cluster 849 ( size 1 ) to 829 ( size 10 ) distance reduction: -214
# Move: 210 | Moving 699 from cluster 336 ( size 1 ) to 333 ( size 9 ) distance reduction: -198
# Move: 211 | Moving 718 from cluster 289 ( size 3 ) to 285 ( size 1 ) distance reduction: -16
# Move: 212 | Moving 22 from cluster 610 ( size 1 ) to 641 ( size 2 ) distance reduction: -76
# Move: 213 | Moving 741 from cluster 716 ( size 1 ) to 726 ( size 3 ) distance reduction: -66
# Move: 214 | Moving 402 from cluster 696 ( size 1 ) to 666 ( size 5 ) distance reduction: -84
# Move: 215 | Moving 549 from cluster 431 ( size 1 ) to 448 ( size 9 ) distance reduction: -158
# Move: 216 | Moving 264 from cluster 176 ( size 1 ) to 173 ( size 6 ) distance reduction: -140
# Move: 217 | Moving 100 from cluster 513 ( size 1 ) to 479 ( size 1 ) distance reduction: -52
# Move: 218 | Moving 91 from cluster 780 ( size 1 ) to 788 ( size 5 ) distance reduction: -110
# Move: 219 | Moving 290 from cluster 45 ( size 1 ) to 47 ( size 1 ) distance reduction: -60
# Move: 220 | Moving 348 from cluster 792 ( size 1 ) to 788 ( size 6 ) distance reduction: -134
# Move: 221 | Moving 915 from cluster 27 ( size 1 ) to 26 ( size 1 ) distance reduction: -60
# Move: 222 | Moving 483 from cluster 708 ( size 1 ) to 721 ( size 7 ) distance reduction: -156
# Move: 223 | Moving 953 from cluster 250 ( size 1 ) to 233 ( size 3 ) distance reduction: -80
# Move: 224 | Moving 743 from cluster 130 ( size 1 ) to 126 ( size 2 ) distance reduction: -70
# Move: 225 | Moving 572 from cluster 35 ( size 1 ) to 334 ( size 1 ) distance reduction: -38
# Move: 226 | Moving 805 from cluster 271 ( size 1 ) to 264 ( size 4 ) distance reduction: -94
# Move: 227 | Moving 234 from cluster 612 ( size 1 ) to 641 ( size 3 ) distance reduction: -96
# Move: 228 | Moving 158 from cluster 17 ( size 1 ) to 19 ( size 2 ) distance reduction: -74
# Move: 229 | Moving 174 from cluster 421 ( size 2 ) to 448 ( size 10 ) distance reduction: -192
# Move: 230 | Moving 327 from cluster 111 ( size 2 ) to 113 ( size 1 ) distance reduction: -36
# Move: 231 | Moving 185 from cluster 984 ( size 1 ) to 979 ( size 5 ) distance reduction: -138
# Move: 232 | Moving 921 from cluster 224 ( size 1 ) to 205 ( size 4 ) distance reduction: -102
# Move: 233 | Moving 623 from cluster 313 ( size 1 ) to 301 ( size 2 ) distance reduction: -66
# Move: 234 | Moving 226 from cluster 251 ( size 2 ) to 206 ( size 1 ) distance reduction: -36
# Move: 235 | Moving 302 from cluster 494 ( size 1 ) to 503 ( size 2 ) distance reduction: -74
# Move: 236 | Moving 160 from cluster 784 ( size 1 ) to 788 ( size 7 ) distance reduction: -158
# Move: 237 | Moving 618 from cluster 181 ( size 1 ) to 173 ( size 7 ) distance reduction: -152
# Move: 238 | Moving 588 from cluster 542 ( size 1 ) to 535 ( size 9 ) distance reduction: -214
# Move: 239 | Moving 956 from cluster 560 ( size 1 ) to 535 ( size 10 ) distance reduction: -232
# Move: 240 | Moving 274 from cluster 43 ( size 1 ) to 47 ( size 2 ) distance reduction: -80
# Move: 241 | Moving 209 from cluster 897 ( size 1 ) to 890 ( size 9 ) distance reduction: -216
# Move: 242 | Moving 997 from cluster 884 ( size 1 ) to 856 ( size 1 ) distance reduction: -62
# Move: 243 | Moving 38 from cluster 954 ( size 1 ) to 961 ( size 5 ) distance reduction: -144
# Move: 244 | Moving 591 from cluster 433 ( size 1 ) to 448 ( size 11 ) distance reduction: -230
# Move: 245 | Moving 984 from cluster 649 ( size 1 ) to 646 ( size 2 ) distance reduction: -66
# Move: 246 | Moving 162 from cluster 395 ( size 4 ) to 381 ( size 9 ) distance reduction: -136
# Move: 247 | Moving 159 from cluster 976 ( size 1 ) to 306 ( size 1 ) distance reduction: -28
# Move: 248 | Moving 183 from cluster 0 ( size 2 ) to 7 ( size 5 ) distance reduction: -126
# Move: 249 | Moving 244 from cluster 703 ( size 1 ) to 721 ( size 8 ) distance reduction: -178
# Move: 250 | Moving 507 from cluster 63 ( size 2 ) to 19 ( size 3 ) distance reduction: -48
# Move: 251 | Moving 54 from cluster 697 ( size 1 ) to 721 ( size 9 ) distance reduction: -188
# Move: 252 | Moving 746 from cluster 631 ( size 1 ) to 641 ( size 4 ) distance reduction: -102
# Move: 253 | Moving 864 from cluster 763 ( size 1 ) to 754 ( size 2 ) distance reduction: -80
# Move: 254 | Moving 181 from cluster 320 ( size 1 ) to 333 ( size 10 ) distance reduction: -250
# Move: 255 | Moving 231 from cluster 493 ( size 1 ) to 500 ( size 2 ) distance reduction: -74
# Move: 256 | Moving 998 from cluster 644 ( size 1 ) to 641 ( size 5 ) distance reduction: -104
# Move: 257 | Moving 952 from cluster 641 ( size 6 ) to 638 ( size 4 ) distance reduction: -22
# Move: 258 | Moving 432 from cluster 213 ( size 1 ) to 205 ( size 5 ) distance reduction: -114
# Move: 259 | Moving 636 from cluster 60 ( size 1 ) to 126 ( size 3 ) distance reduction: -82
# Move: 260 | Moving 281 from cluster 379 ( size 1 ) to 381 ( size 10 ) distance reduction: -206
# Move: 261 | Moving 731 from cluster 629 ( size 1 ) to 641 ( size 5 ) distance reduction: -124
# Move: 262 | Moving 49 from cluster 675 ( size 1 ) to 683 ( size 3 ) distance reduction: -98
# Move: 263 | Moving 488 from cluster 681 ( size 1 ) to 683 ( size 4 ) distance reduction: -84
# Move: 264 | Moving 650 from cluster 932 ( size 1 ) to 935 ( size 2 ) distance reduction: -76
# Move: 265 | Moving 603 from cluster 512 ( size 1 ) to 486 ( size 2 ) distance reduction: -66
# Move: 266 | Moving 89 from cluster 401 ( size 1 ) to 381 ( size 11 ) distance reduction: -234
# Move: 267 | Moving 62 from cluster 517 ( size 1 ) to 535 ( size 11 ) distance reduction: -248
# Move: 268 | Moving 60 from cluster 677 ( size 1 ) to 683 ( size 5 ) distance reduction: -136
# Move: 269 | Moving 74 from cluster 741 ( size 2 ) to 740 ( size 2 ) distance reduction: -50
# Move: 270 | Moving 215 from cluster 749 ( size 1 ) to 740 ( size 3 ) distance reduction: -84
# Move: 271 | Moving 868 from cluster 915 ( size 1 ) to 890 ( size 10 ) distance reduction: -232
# Move: 272 | Moving 315 from cluster 851 ( size 1 ) to 823 ( size 2 ) distance reduction: -36
# Move: 273 | Moving 999 from cluster 69 ( size 1 ) to 19 ( size 4 ) distance reduction: -94
# Move: 274 | Moving 604 from cluster 125 ( size 1 ) to 359 ( size 2 ) distance reduction: -40
# Move: 275 | Moving 961 from cluster 292 ( size 1 ) to 289 ( size 2 ) distance reduction: -74
# Move: 276 | Moving 742 from cluster 243 ( size 1 ) to 233 ( size 4 ) distance reduction: -94
# Move: 277 | Moving 186 from cluster 785 ( size 1 ) to 788 ( size 8 ) distance reduction: -180
# Move: 278 | Moving 444 from cluster 267 ( size 1 ) to 301 ( size 3 ) distance reduction: -90
# Move: 279 | Moving 944 from cluster 503 ( size 3 ) to 490 ( size 1 ) distance reduction: -12
# Move: 280 | Moving 413 from cluster 327 ( size 1 ) to 333 ( size 11 ) distance reduction: -198
# Move: 281 | Moving 874 from cluster 881 ( size 1 ) to 862 ( size 7 ) distance reduction: -206
# Move: 282 | Moving 647 from cluster 50 ( size 1 ) to 47 ( size 3 ) distance reduction: -94
# Move: 283 | Moving 196 from cluster 322 ( size 1 ) to 333 ( size 12 ) distance reduction: -250
# Move: 284 | Moving 585 from cluster 330 ( size 1 ) to 333 ( size 13 ) distance reduction: -280
# Move: 285 | Moving 284 from cluster 44 ( size 1 ) to 47 ( size 4 ) distance reduction: -114
# Move: 286 | Moving 565 from cluster 397 ( size 1 ) to 381 ( size 12 ) distance reduction: -236
# Move: 287 | Moving 589 from cluster 68 ( size 1 ) to 34 ( size 5 ) distance reduction: -74
# Move: 288 | Moving 695 from cluster 803 ( size 1 ) to 788 ( size 9 ) distance reduction: -192
# Move: 289 | Moving 25 from cluster 978 ( size 1 ) to 979 ( size 6 ) distance reduction: -116
# Move: 290 | Moving 502 from cluster 416 ( size 1 ) to 417 ( size 1 ) distance reduction: -48
# Move: 291 | Moving 361 from cluster 614 ( size 1 ) to 641 ( size 6 ) distance reduction: -136
# Move: 292 | Moving 885 from cluster 889 ( size 1 ) to 861 ( size 1 ) distance reduction: -36
# Move: 293 | Moving 40 from cluster 819 ( size 1 ) to 829 ( size 11 ) distance reduction: -234
# Move: 294 | Moving 516 from cluster 430 ( size 1 ) to 448 ( size 12 ) distance reduction: -240
# Move: 295 | Moving 321 from cluster 368 ( size 1 ) to 333 ( size 14 ) distance reduction: -146
# Move: 296 | Moving 564 from cluster 601 ( size 1 ) to 593 ( size 4 ) distance reduction: -116
# Move: 297 | Moving 871 from cluster 454 ( size 1 ) to 434 ( size 1 ) distance reduction: -50
# Move: 298 | Moving 499 from cluster 563 ( size 1 ) to 535 ( size 12 ) distance reduction: -138
# Move: 299 | Moving 188 from cluster 734 ( size 1 ) to 721 ( size 10 ) distance reduction: -176
# Move: 300 | Moving 246 from cluster 751 ( size 1 ) to 740 ( size 4 ) distance reduction: -104
# Move: 301 | Moving 679 from cluster 546 ( size 1 ) to 535 ( size 13 ) distance reduction: -252
# Move: 302 | Moving 925 from cluster 12 ( size 1 ) to 7 ( size 6 ) distance reduction: -152
# Move: 303 | Moving 899 from cluster 882 ( size 1 ) to 862 ( size 8 ) distance reduction: -176
# Move: 304 | Moving 90 from cluster 196 ( size 1 ) to 161 ( size 14 ) distance reduction: -244
# Move: 305 | Moving 762 from cluster 878 ( size 1 ) to 862 ( size 9 ) distance reduction: -246
# Move: 306 | Moving 609 from cluster 434 ( size 2 ) to 448 ( size 13 ) distance reduction: -254
# Move: 307 | Moving 817 from cluster 510 ( size 1 ) to 515 ( size 1 ) distance reduction: -40
# Move: 308 | Moving 375 from cluster 724 ( size 1 ) to 721 ( size 11 ) distance reduction: -206
# Move: 309 | Moving 747 from cluster 717 ( size 1 ) to 721 ( size 12 ) distance reduction: -254
# Move: 310 | Moving 96 from cluster 305 ( size 1 ) to 264 ( size 5 ) distance reduction: -90
# Move: 311 | Moving 858 from cluster 652 ( size 1 ) to 641 ( size 7 ) distance reduction: -130
# Move: 312 | Moving 210 from cluster 188 ( size 2 ) to 187 ( size 2 ) distance reduction: -34
# Move: 313 | Moving 714 from cluster 56 ( size 1 ) to 34 ( size 6 ) distance reduction: -92
# Move: 314 | Moving 268 from cluster 378 ( size 1 ) to 381 ( size 13 ) distance reduction: -302
# Move: 315 | Moving 630 from cluster 760 ( size 1 ) to 740 ( size 5 ) distance reduction: -120
# Move: 316 | Moving 50 from cluster 74 ( size 1 ) to 98 ( size 6 ) distance reduction: -122
# Move: 317 | Moving 442 from cluster 295 ( size 2 ) to 264 ( size 6 ) distance reduction: -58
# Move: 318 | Moving 553 from cluster 852 ( size 1 ) to 642 ( size 1 ) distance reduction: -38
# Move: 319 | Moving 30 from cluster 187 ( size 3 ) to 186 ( size 1 ) distance reduction: -34
# Move: 320 | Moving 702 from cluster 550 ( size 1 ) to 535 ( size 14 ) distance reduction: -282
# Move: 321 | Moving 474 from cluster 887 ( size 1 ) to 886 ( size 1 ) distance reduction: -32
# Move: 322 | Moving 476 from cluster 155 ( size 1 ) to 161 ( size 15 ) distance reduction: -330
# Move: 323 | Moving 407 from cluster 212 ( size 1 ) to 205 ( size 6 ) distance reduction: -156
# Move: 324 | Moving 620 from cluster 648 ( size 1 ) to 638 ( size 5 ) distance reduction: -122
# Move: 325 | Moving 454 from cluster 385 ( size 1 ) to 381 ( size 14 ) distance reduction: -282
# Move: 326 | Moving 2 from cluster 227 ( size 1 ) to 233 ( size 5 ) distance reduction: -136
# Move: 327 | Moving 263 from cluster 753 ( size 1 ) to 740 ( size 6 ) distance reduction: -140
# Move: 328 | Moving 494 from cluster 574 ( size 4 ) to 570 ( size 1 ) distance reduction: -2
# Move: 329 | Moving 957 from cluster 446 ( size 2 ) to 448 ( size 14 ) distance reduction: -270
# Move: 330 | Moving 621 from cluster 91 ( size 1 ) to 98 ( size 7 ) distance reduction: -154
# Move: 331 | Moving 16 from cluster 855 ( size 2 ) to 862 ( size 10 ) distance reduction: -264
# Move: 332 | Moving 939 from cluster 350 ( size 1 ) to 333 ( size 15 ) distance reduction: -322
# Move: 333 | Moving 579 from cluster 22 ( size 1 ) to 19 ( size 5 ) distance reduction: -112
# Move: 334 | Moving 671 from cluster 37 ( size 1 ) to 34 ( size 7 ) distance reduction: -146
# Move: 335 | Moving 357 from cluster 149 ( size 1 ) to 161 ( size 16 ) distance reduction: -312
# Move: 336 | Moving 451 from cluster 726 ( size 4 ) to 721 ( size 13 ) distance reduction: -208
# Move: 337 | Moving 715 from cluster 506 ( size 1 ) to 476 ( size 2 ) distance reduction: -70
# Move: 338 | Moving 400 from cluster 404 ( size 1 ) to 234 ( size 1 ) distance reduction: -40
# Move: 339 | Moving 220 from cluster 568 ( size 1 ) to 570 ( size 2 ) distance reduction: -82
# Move: 340 | Moving 763 from cluster 25 ( size 1 ) to 19 ( size 6 ) distance reduction: -146
# Move: 341 | Moving 484 from cluster 573 ( size 1 ) to 570 ( size 3 ) distance reduction: -110
# Move: 342 | Moving 569 from cluster 625 ( size 1 ) to 641 ( size 8 ) distance reduction: -182
# Move: 343 | Moving 865 from cluster 764 ( size 1 ) to 740 ( size 7 ) distance reduction: -164
# Move: 344 | Moving 648 from cluster 359 ( size 3 ) to 360 ( size 1 ) distance reduction: -26
# Move: 345 | Moving 512 from cluster 645 ( size 1 ) to 641 ( size 9 ) distance reduction: -184
# Move: 346 | Moving 712 from cluster 551 ( size 4 ) to 535 ( size 15 ) distance reduction: -258
# Move: 347 | Moving 782 from cluster 604 ( size 1 ) to 593 ( size 5 ) distance reduction: -130
# Move: 348 | Moving 590 from cluster 711 ( size 1 ) to 721 ( size 14 ) distance reduction: -290
# Move: 349 | Moving 497 from cluster 575 ( size 1 ) to 566 ( size 1 ) distance reduction: -52
# Move: 350 | Moving 3 from cluster 467 ( size 1 ) to 476 ( size 3 ) distance reduction: -100
# Move: 351 | Moving 627 from cluster 690 ( size 1 ) to 667 ( size 1 ) distance reduction: -44
# Move: 352 | Moving 4 from cluster 654 ( size 1 ) to 666 ( size 6 ) distance reduction: -156
# Move: 353 | Moving 126 from cluster 854 ( size 1 ) to 101 ( size 3 ) distance reduction: -64
# Move: 354 | Moving 533 from cluster 988 ( size 1 ) to 979 ( size 7 ) distance reduction: -144
# Move: 355 | Moving 170 from cluster 678 ( size 1 ) to 683 ( size 6 ) distance reduction: -146
# Move: 356 | Moving 345 from cluster 613 ( size 1 ) to 641 ( size 10 ) distance reduction: -214
# Move: 357 | Moving 190 from cluster 786 ( size 2 ) to 788 ( size 10 ) distance reduction: -182
# Move: 358 | Moving 148 from cluster 860 ( size 1 ) to 862 ( size 11 ) distance reduction: -290
# Move: 359 | Moving 377 from cluster 150 ( size 1 ) to 161 ( size 17 ) distance reduction: -340
# Move: 360 | Moving 827 from cluster 995 ( size 1 ) to 979 ( size 8 ) distance reduction: -200
# Move: 361 | Moving 548 from cluster 87 ( size 1 ) to 98 ( size 8 ) distance reduction: -180
# Move: 362 | Moving 890 from cluster 588 ( size 1 ) to 570 ( size 4 ) distance reduction: -126
# Move: 363 | Moving 854 from cluster 637 ( size 1 ) to 641 ( size 11 ) distance reduction: -236
# Move: 364 | Moving 804 from cluster 498 ( size 1 ) to 500 ( size 3 ) distance reduction: -94
# Move: 365 | Moving 51 from cluster 676 ( size 1 ) to 683 ( size 7 ) distance reduction: -158
# Move: 366 | Moving 28 from cluster 314 ( size 2 ) to 264 ( size 7 ) distance reduction: -110
# Move: 367 | Moving 165 from cluster 375 ( size 1 ) to 381 ( size 15 ) distance reduction: -258
# Move: 368 | Moving 835 from cluster 636 ( size 1 ) to 638 ( size 6 ) distance reduction: -144
# Move: 369 | Moving 179 from cluster 594 ( size 1 ) to 593 ( size 6 ) distance reduction: -166
# Move: 370 | Moving 39 from cluster 318 ( size 1 ) to 333 ( size 16 ) distance reduction: -356
# Move: 371 | Moving 808 from cluster 970 ( size 1 ) to 961 ( size 6 ) distance reduction: -142
# Move: 372 | Moving 757 from cluster 718 ( size 1 ) to 721 ( size 15 ) distance reduction: -266
# Move: 373 | Moving 169 from cluster 319 ( size 1 ) to 333 ( size 17 ) distance reduction: -372
# Move: 374 | Moving 684 from cluster 547 ( size 1 ) to 535 ( size 16 ) distance reduction: -294
# Move: 375 | Moving 265 from cluster 263 ( size 1 ) to 264 ( size 8 ) distance reduction: -164
# Move: 376 | Moving 411 from cluster 4 ( size 1 ) to 7 ( size 7 ) distance reduction: -182
# Move: 377 | Moving 552 from cluster 931 ( size 1 ) to 935 ( size 3 ) distance reduction: -92
# Move: 378 | Moving 913 from cluster 400 ( size 1 ) to 381 ( size 16 ) distance reduction: -238
# Move: 379 | Moving 739 from cluster 769 ( size 1 ) to 740 ( size 8 ) distance reduction: -154
# Move: 380 | Moving 305 from cluster 310 ( size 1 ) to 314 ( size 1 ) distance reduction: -48
# Move: 381 | Moving 389 from cluster 126 ( size 4 ) to 98 ( size 9 ) distance reduction: -100
# Move: 382 | Moving 346 from cluster 667 ( size 2 ) to 666 ( size 7 ) distance reduction: -168
# Move: 383 | Moving 644 from cluster 198 ( size 1 ) to 146 ( size 1 ) distance reduction: -54
# Move: 384 | Moving 67 from cluster 779 ( size 1 ) to 788 ( size 11 ) distance reduction: -252
# Move: 385 | Moving 880 from cluster 732 ( size 1 ) to 721 ( size 16 ) distance reduction: -314
# Move: 386 | Moving 823 from cluster 441 ( size 1 ) to 448 ( size 15 ) distance reduction: -284
# Move: 387 | Moving 568 from cluster 89 ( size 1 ) to 98 ( size 10 ) distance reduction: -194
# Move: 388 | Moving 107 from cluster 822 ( size 1 ) to 829 ( size 12 ) distance reduction: -260
# Move: 389 | Moving 832 from cluster 719 ( size 1 ) to 721 ( size 17 ) distance reduction: -276
# Move: 390 | Moving 583 from cluster 874 ( size 1 ) to 862 ( size 12 ) distance reduction: -288
# Move: 391 | Moving 426 from cluster 497 ( size 1 ) to 490 ( size 2 ) distance reduction: -74
# Move: 392 | Moving 29 from cluster 489 ( size 1 ) to 500 ( size 4 ) distance reduction: -98
# Move: 393 | Moving 82 from cluster 115 ( size 1 ) to 116 ( size 2 ) distance reduction: -54
# Move: 394 | Moving 594 from cluster 158 ( size 1 ) to 161 ( size 18 ) distance reduction: -278
# Move: 395 | Moving 705 from cluster 216 ( size 1 ) to 205 ( size 7 ) distance reduction: -178
# Move: 396 | Moving 920 from cluster 357 ( size 1 ) to 356 ( size 1 ) distance reduction: -58
# Move: 397 | Moving 546 from cluster 236 ( size 1 ) to 233 ( size 6 ) distance reduction: -148
# Move: 398 | Moving 7 from cluster 228 ( size 1 ) to 233 ( size 7 ) distance reduction: -170
# Move: 399 | Moving 670 from cluster 912 ( size 1 ) to 890 ( size 11 ) distance reduction: -226
# Move: 400 | Moving 807 from cluster 311 ( size 1 ) to 264 ( size 9 ) distance reduction: -114
# Move: 401 | Moving 202 from cluster 377 ( size 1 ) to 381 ( size 17 ) distance reduction: -300
# Move: 402 | Moving 27 from cluster 199 ( size 1 ) to 666 ( size 8 ) distance reduction: -72
# Move: 403 | Moving 157 from cluster 748 ( size 1 ) to 740 ( size 9 ) distance reduction: -180
# Move: 404 | Moving 297 from cluster 80 ( size 1 ) to 98 ( size 11 ) distance reduction: -234
# Move: 405 | Moving 450 from cluster 928 ( size 1 ) to 935 ( size 4 ) distance reduction: -108
# Move: 406 | Moving 9 from cluster 369 ( size 1 ) to 381 ( size 18 ) distance reduction: -394
# Move: 407 | Moving 394 from cluster 836 ( size 2 ) to 829 ( size 13 ) distance reduction: -238
# Move: 408 | Moving 344 from cluster 514 ( size 1 ) to 515 ( size 2 ) distance reduction: -44
# Move: 409 | Moving 537 from cluster 909 ( size 1 ) to 890 ( size 12 ) distance reduction: -260
# Move: 410 | Moving 631 from cluster 947 ( size 1 ) to 940 ( size 4 ) distance reduction: -114
# Move: 411 | Moving 660 from cluster 564 ( size 1 ) to 20 ( size 1 ) distance reduction: -34
# Move: 412 | Moving 765 from cluster 837 ( size 1 ) to 829 ( size 14 ) distance reduction: -254
# Move: 413 | Moving 524 from cluster 257 ( size 1 ) to 26 ( size 2 ) distance reduction: -44
# Move: 414 | Moving 304 from cluster 790 ( size 1 ) to 788 ( size 12 ) distance reduction: -250
# Move: 415 | Moving 613 from cluster 160 ( size 1 ) to 161 ( size 19 ) distance reduction: -398
# Move: 416 | Moving 698 from cluster 581 ( size 1 ) to 570 ( size 5 ) distance reduction: -156
# Move: 417 | Moving 683 from cluster 579 ( size 1 ) to 570 ( size 6 ) distance reduction: -132
# Move: 418 | Moving 800 from cluster 969 ( size 1 ) to 961 ( size 7 ) distance reduction: -108
# Move: 419 | Moving 482 from cluster 306 ( size 2 ) to 264 ( size 10 ) distance reduction: -88
# Move: 420 | Moving 704 from cluster 337 ( size 1 ) to 333 ( size 18 ) distance reduction: -356
# Move: 421 | Moving 980 from cluster 226 ( size 1 ) to 205 ( size 8 ) distance reduction: -152
# Move: 422 | Moving 576 from cluster 562 ( size 1 ) to 535 ( size 17 ) distance reduction: -76
# Move: 423 | Moving 6 from cluster 468 ( size 1 ) to 476 ( size 4 ) distance reduction: -106
# Move: 424 | Moving 303 from cluster 451 ( size 1 ) to 448 ( size 16 ) distance reduction: -300
# Move: 425 | Moving 996 from cluster 137 ( size 1 ) to 116 ( size 3 ) distance reduction: -72
# Move: 426 | Moving 460 from cluster 122 ( size 1 ) to 118 ( size 1 ) distance reduction: -40
# Move: 427 | Moving 493 from cluster 20 ( size 2 ) to 19 ( size 7 ) distance reduction: -172
# Move: 428 | Moving 187 from cluster 885 ( size 1 ) to 886 ( size 2 ) distance reduction: -34
# Move: 429 | Moving 156 from cluster 303 ( size 1 ) to 264 ( size 11 ) distance reduction: -86
# Move: 430 | Moving 18 from cluster 186 ( size 2 ) to 187 ( size 2 ) distance reduction: -28
# Move: 431 | Moving 428 from cluster 944 ( size 1 ) to 940 ( size 5 ) distance reduction: -134
# Move: 432 | Moving 257 from cluster 175 ( size 1 ) to 173 ( size 8 ) distance reduction: -200
# Move: 433 | Moving 545 from cluster 539 ( size 1 ) to 535 ( size 18 ) distance reduction: -362
# Move: 434 | Moving 551 from cluster 798 ( size 1 ) to 788 ( size 13 ) distance reduction: -232
# Move: 435 | Moving 737 from cluster 218 ( size 1 ) to 205 ( size 9 ) distance reduction: -190
# Move: 436 | Moving 820 from cluster 343 ( size 1 ) to 333 ( size 19 ) distance reduction: -426
# Move: 437 | Moving 655 from cluster 483 ( size 1 ) to 476 ( size 5 ) distance reduction: -130
# Move: 438 | Moving 145 from cluster 660 ( size 1 ) to 666 ( size 9 ) distance reduction: -144
# Move: 439 | Moving 673 from cluster 602 ( size 1 ) to 593 ( size 7 ) distance reduction: -174
# Move: 440 | Moving 902 from cluster 247 ( size 1 ) to 233 ( size 8 ) distance reduction: -168
# Move: 441 | Moving 333 from cluster 460 ( size 1 ) to 448 ( size 17 ) distance reduction: -210
# Move: 442 | Moving 806 from cluster 341 ( size 1 ) to 333 ( size 20 ) distance reduction: -394
# Move: 443 | Moving 745 from cluster 53 ( size 1 ) to 5 ( size 1 ) distance reduction: -48
# Move: 444 | Moving 605 from cluster 800 ( size 1 ) to 788 ( size 14 ) distance reduction: -294
# Move: 445 | Moving 597 from cluster 258 ( size 1 ) to 203 ( size 2 ) distance reduction: -46
# Move: 446 | Moving 247 from cluster 145 ( size 1 ) to 161 ( size 20 ) distance reduction: -440
# Move: 447 | Moving 877 from cluster 953 ( size 1 ) to 486 ( size 3 ) distance reduction: -34
# Move: 448 | Moving 329 from cluster 424 ( size 1 ) to 448 ( size 18 ) distance reduction: -266
# Move: 449 | Moving 275 from cluster 754 ( size 3 ) to 740 ( size 10 ) distance reduction: -178
# Move: 450 | Moving 889 from cluster 997 ( size 1 ) to 979 ( size 9 ) distance reduction: -228
# Move: 451 | Moving 53 from cluster 102 ( size 1 ) to 101 ( size 4 ) distance reduction: -112
# Move: 452 | Moving 837 from cluster 817 ( size 1 ) to 829 ( size 15 ) distance reduction: -136
# Move: 453 | Moving 926 from cluster 97 ( size 1 ) to 98 ( size 12 ) distance reduction: -228
# Move: 454 | Moving 176 from cluster 110 ( size 1 ) to 109 ( size 1 ) distance reduction: -52
# Move: 455 | Moving 79 from cluster 280 ( size 1 ) to 289 ( size 3 ) distance reduction: -94
# Move: 456 | Moving 629 from cluster 461 ( size 1 ) to 448 ( size 19 ) distance reduction: -240
# Move: 457 | Moving 857 from cluster 586 ( size 1 ) to 570 ( size 7 ) distance reduction: -186
# Move: 458 | Moving 529 from cluster 853 ( size 1 ) to 829 ( size 16 ) distance reduction: -92
# Move: 459 | Moving 667 from cluster 968 ( size 1 ) to 961 ( size 8 ) distance reduction: -132
# Move: 460 | Moving 201 from cluster 661 ( size 1 ) to 666 ( size 10 ) distance reduction: -180
# Move: 461 | Moving 112 from cluster 893 ( size 1 ) to 890 ( size 13 ) distance reduction: -264
# Move: 462 | Moving 44 from cluster 490 ( size 3 ) to 500 ( size 5 ) distance reduction: -88
# Move: 463 | Moving 958 from cluster 999 ( size 1 ) to 979 ( size 10 ) distance reduction: -234
# Move: 464 | Moving 273 from cluster 133 ( size 1 ) to 116 ( size 4 ) distance reduction: -72
# Move: 465 | Moving 818 from cluster 554 ( size 1 ) to 535 ( size 19 ) distance reduction: -364
# Move: 466 | Moving 504 from cluster 907 ( size 1 ) to 890 ( size 14 ) distance reduction: -318
# Move: 467 | Moving 330 from cluster 298 ( size 1 ) to 264 ( size 12 ) distance reduction: -152
# Move: 468 | Moving 94 from cluster 766 ( size 1 ) to 771 ( size 1 ) distance reduction: -24
# Move: 469 | Moving 970 from cluster 778 ( size 1 ) to 570 ( size 8 ) distance reduction: -34
# Move: 470 | Moving 544 from cluster 235 ( size 1 ) to 233 ( size 9 ) distance reduction: -210
# Move: 471 | Moving 445 from cluster 960 ( size 1 ) to 961 ( size 9 ) distance reduction: -180
# Move: 472 | Moving 733 from cluster 630 ( size 1 ) to 641 ( size 12 ) distance reduction: -248
# Move: 473 | Moving 682 from cluster 508 ( size 1 ) to 476 ( size 6 ) distance reduction: -72
# Move: 474 | Moving 131 from cluster 659 ( size 1 ) to 666 ( size 11 ) distance reduction: -198
# Move: 475 | Moving 872 from cluster 96 ( size 1 ) to 73 ( size 1 ) distance reduction: -54
# Move: 476 | Moving 829 from cluster 499 ( size 1 ) to 500 ( size 6 ) distance reduction: -154
# Move: 477 | Moving 965 from cluster 973 ( size 2 ) to 961 ( size 10 ) distance reduction: -202
# Move: 478 | Moving 238 from cluster 528 ( size 1 ) to 535 ( size 20 ) distance reduction: -366
# Move: 479 | Moving 133 from cluster 982 ( size 1 ) to 979 ( size 11 ) distance reduction: -248
# Move: 480 | Moving 905 from cluster 26 ( size 3 ) to 19 ( size 8 ) distance reduction: -146
# Move: 481 | Moving 709 from cluster 464 ( size 2 ) to 448 ( size 20 ) distance reduction: -266
# Move: 482 | Moving 892 from cluster 348 ( size 1 ) to 333 ( size 21 ) distance reduction: -390
# Move: 483 | Moving 879 from cluster 106 ( size 1 ) to 101 ( size 5 ) distance reduction: -128
# Move: 484 | Moving 788 from cluster 771 ( size 2 ) to 194 ( size 1 ) distance reduction: -50
# Move: 485 | Moving 109 from cluster 981 ( size 2 ) to 979 ( size 12 ) distance reduction: -216
# Move: 486 | Moving 501 from cluster 795 ( size 1 ) to 788 ( size 15 ) distance reduction: -328
# Move: 487 | Moving 522 from cluster 21 ( size 1 ) to 19 ( size 9 ) distance reduction: -192
# Move: 488 | Moving 19 from cluster 109 ( size 2 ) to 113 ( size 2 ) distance reduction: -44
# Move: 489 | Moving 542 from cluster 354 ( size 1 ) to 356 ( size 2 ) distance reduction: -78
# Move: 490 | Moving 541 from cluster 930 ( size 1 ) to 935 ( size 5 ) distance reduction: -118
# Move: 491 | Moving 697 from cluster 183 ( size 1 ) to 173 ( size 9 ) distance reduction: -230
# Move: 492 | Moving 310 from cluster 569 ( size 1 ) to 570 ( size 9 ) distance reduction: -210
# Move: 493 | Moving 285 from cluster 957 ( size 1 ) to 961 ( size 11 ) distance reduction: -254
# Move: 494 | Moving 421 from cluster 426 ( size 1 ) to 448 ( size 21 ) distance reduction: -376
# Move: 495 | Moving 431 from cluster 870 ( size 1 ) to 862 ( size 13 ) distance reduction: -292
# Move: 496 | Moving 515 from cluster 929 ( size 1 ) to 935 ( size 6 ) distance reduction: -152
# Move: 497 | Moving 153 from cluster 823 ( size 3 ) to 829 ( size 17 ) distance reduction: -310
# Move: 498 | Moving 255 from cluster 323 ( size 1 ) to 333 ( size 22 ) distance reduction: -456
# Move: 499 | Moving 324 from cluster 147 ( size 1 ) to 161 ( size 21 ) distance reduction: -362
# Move: 500 | Moving 797 from cluster 808 ( size 1 ) to 788 ( size 16 ) distance reduction: -290
# Move: 501 | Moving 498 from cluster 48 ( size 1 ) to 47 ( size 5 ) distance reduction: -128
# Move: 502 | Moving 903 from cluster 40 ( size 2 ) to 34 ( size 8 ) distance reduction: -166
# Move: 503 | Moving 635 from cluster 253 ( size 1 ) to 205 ( size 10 ) distance reduction: -168
# Move: 504 | Moving 161 from cluster 693 ( size 1 ) to 683 ( size 8 ) distance reduction: -130
# Move: 505 | Moving 369 from cluster 403 ( size 1 ) to 381 ( size 19 ) distance reduction: -196
# Move: 506 | Moving 166 from cluster 76 ( size 1 ) to 98 ( size 13 ) distance reduction: -276
# Move: 507 | Moving 132 from cluster 925 ( size 2 ) to 935 ( size 7 ) distance reduction: -158
# Move: 508 | Moving 625 from cluster 577 ( size 1 ) to 570 ( size 10 ) distance reduction: -226
# Move: 509 | Moving 547 from cluster 623 ( size 1 ) to 641 ( size 13 ) distance reduction: -292
# Move: 510 | Moving 245 from cluster 61 ( size 1 ) to 47 ( size 6 ) distance reduction: -34
# Move: 511 | Moving 550 from cluster 653 ( size 1 ) to 7 ( size 8 ) distance reduction: -64
# Move: 512 | Moving 72 from cluster 519 ( size 1 ) to 535 ( size 21 ) distance reduction: -398
# Move: 513 | Moving 929 from cluster 685 ( size 1 ) to 683 ( size 9 ) distance reduction: -206
# Move: 514 | Moving 319 from cluster 136 ( size 1 ) to 113 ( size 3 ) distance reduction: -64
# ...
# Move: 1222 | Moving 95 from cluster 505 ( size 4 ) to 273 ( size 4 ) distance reduction: -100
# Move: 1223 | Moving 989 from cluster 356 ( size 4 ) to 360 ( size 7 ) distance reduction: -22
# --- 6 / 20 ---
# Move: 1224 | Moving 553 from cluster 642 ( size 3 ) to 641 ( size 43 ) distance reduction: -10
# Move: 1225 | Moving 788 from cluster 505 ( size 3 ) to 187 ( size 4 ) distance reduction: -10
# Move: 1226 | Moving 836 from cluster 187 ( size 5 ) to 273 ( size 5 ) distance reduction: -100
# Move: 1227 | Moving 744 from cluster 187 ( size 4 ) to 273 ( size 6 ) distance reduction: -44
# Move: 1228 | Moving 245 from cluster 47 ( size 12 ) to 59 ( size 2 ) distance reduction: -22
# Move: 1229 | Moving 406 from cluster 360 ( size 8 ) to 356 ( size 3 ) distance reduction: -12
# Move: 1230 | Moving 424 from cluster 118 ( size 10 ) to 59 ( size 3 ) distance reduction: -64
# Move: 1231 | Moving 910 from cluster 356 ( size 4 ) to 360 ( size 7 ) distance reduction: -46
# Move: 1232 | Moving 756 from cluster 505 ( size 2 ) to 273 ( size 7 ) distance reduction: -64
# Move: 1233 | Moving 648 from cluster 360 ( size 8 ) to 356 ( size 3 ) distance reduction: -8
# Move: 1234 | Moving 664 from cluster 356 ( size 4 ) to 360 ( size 7 ) distance reduction: -70
# Move: 1235 | Moving 439 from cluster 187 ( size 3 ) to 479 ( size 1 ) distance reduction: -64
# Move: 1236 | Moving 982 from cluster 116 ( size 2 ) to 118 ( size 9 ) distance reduction: -18
# Move: 1237 | Moving 604 from cluster 360 ( size 8 ) to 113 ( size 8 ) distance reduction: -68
# Move: 1238 | Moving 989 from cluster 360 ( size 7 ) to 356 ( size 3 ) distance reduction: -48
# Move: 1239 | Moving 474 from cluster 775 ( size 4 ) to 151 ( size 1 ) distance reduction: -54
# --- 7 / 20 ---
# Move: 1240 | Moving 989 from cluster 356 ( size 4 ) to 360 ( size 6 ) distance reduction: -24
# Move: 1241 | Moving 94 from cluster 505 ( size 1 ) to 187 ( size 2 ) distance reduction: -4
# Move: 1242 | Moving 553 from cluster 641 ( size 44 ) to 642 ( size 2 ) distance reduction: -62
# Move: 1243 | Moving 910 from cluster 360 ( size 7 ) to 356 ( size 3 ) distance reduction: -40
# Move: 1244 | Moving 666 from cluster 775 ( size 3 ) to 151 ( size 2 ) distance reduction: -14
# Move: 1245 | Moving 664 from cluster 360 ( size 6 ) to 356 ( size 4 ) distance reduction: -14
# Move: 1246 | Moving 474 from cluster 151 ( size 3 ) to 7 ( size 20 ) distance reduction: -20
# Move: 1247 | Moving 138 from cluster 360 ( size 5 ) to 356 ( size 5 ) distance reduction: -10
# Move: 1248 | Moving 648 from cluster 356 ( size 6 ) to 360 ( size 4 ) distance reduction: -28
# Move: 1249 | Moving 604 from cluster 113 ( size 9 ) to 360 ( size 5 ) distance reduction: -14
# Move: 1250 | Moving 542 from cluster 360 ( size 6 ) to 356 ( size 5 ) distance reduction: -6
# Move: 1251 | Moving 982 from cluster 118 ( size 10 ) to 116 ( size 1 ) distance reduction: -54
# Move: 1252 | Moving 406 from cluster 356 ( size 6 ) to 360 ( size 5 ) distance reduction: -36
# Move: 1253 | Moving 772 from cluster 360 ( size 6 ) to 356 ( size 5 ) distance reduction: -48
# Move: 1254 | Moving 245 from cluster 59 ( size 4 ) to 47 ( size 11 ) distance reduction: -68
# Move: 1255 | Moving 744 from cluster 273 ( size 8 ) to 479 ( size 2 ) distance reduction: -32
# Move: 1256 | Moving 159 from cluster 775 ( size 2 ) to 151 ( size 2 ) distance reduction: -18
# --- 8 / 20 ---
# Move: 1257 | Moving 788 from cluster 187 ( size 3 ) to 479 ( size 3 ) distance reduction: -44
# Move: 1258 | Moving 982 from cluster 116 ( size 2 ) to 118 ( size 9 ) distance reduction: -18
# Move: 1259 | Moving 648 from cluster 360 ( size 5 ) to 356 ( size 6 ) distance reduction: -48
# Move: 1260 | Moving 542 from cluster 356 ( size 7 ) to 360 ( size 4 ) distance reduction: -6
# Move: 1261 | Moving 744 from cluster 479 ( size 4 ) to 273 ( size 7 ) distance reduction: -38
# Move: 1262 | Moving 772 from cluster 356 ( size 6 ) to 360 ( size 5 ) distance reduction: -64
# Move: 1263 | Moving 910 from cluster 356 ( size 5 ) to 360 ( size 6 ) distance reduction: -34
# Move: 1264 | Moving 560 from cluster 356 ( size 4 ) to 360 ( size 7 ) distance reduction: -4
# Move: 1265 | Moving 474 from cluster 7 ( size 21 ) to 151 ( size 3 ) distance reduction: -32
# Move: 1266 | Moving 989 from cluster 360 ( size 8 ) to 356 ( size 3 ) distance reduction: -54
# Move: 1267 | Moving 664 from cluster 356 ( size 4 ) to 360 ( size 7 ) distance reduction: -38
# Move: 1268 | Moving 138 from cluster 356 ( size 3 ) to 360 ( size 8 ) distance reduction: -62
# Move: 1269 | Moving 604 from cluster 360 ( size 9 ) to 113 ( size 8 ) distance reduction: -76
# Move: 1270 | Moving 406 from cluster 360 ( size 8 ) to 356 ( size 2 ) distance reduction: -34
# Move: 1271 | Moving 666 from cluster 151 ( size 4 ) to 775 ( size 1 ) distance reduction: -78
# Move: 1272 | Moving 245 from cluster 47 ( size 12 ) to 59 ( size 3 ) distance reduction: -4
# Move: 1273 | Moving 553 from cluster 642 ( size 3 ) to 641 ( size 43 ) distance reduction: -10
# --- 9 / 20 ---
# Move: 1274 | Moving 982 from cluster 118 ( size 10 ) to 116 ( size 1 ) distance reduction: -54
# Move: 1275 | Moving 604 from cluster 113 ( size 9 ) to 356 ( size 3 ) distance reduction: -28
# Move: 1276 | Moving 788 from cluster 479 ( size 3 ) to 187 ( size 2 ) distance reduction: -30
# Move: 1277 | Moving 424 from cluster 59 ( size 4 ) to 118 ( size 9 ) distance reduction: -8
# Move: 1278 | Moving 406 from cluster 356 ( size 4 ) to 360 ( size 7 ) distance reduction: -40
# Move: 1279 | Moving 474 from cluster 151 ( size 3 ) to 775 ( size 2 ) distance reduction: -58
# Move: 1280 | Moving 94 from cluster 187 ( size 3 ) to 98 ( size 40 ) distance reduction: -4
# Move: 1281 | Moving 989 from cluster 356 ( size 3 ) to 360 ( size 8 ) distance reduction: -26
# Move: 1282 | Moving 744 from cluster 273 ( size 8 ) to 187 ( size 2 ) distance reduction: -40
# Move: 1283 | Moving 664 from cluster 360 ( size 9 ) to 356 ( size 2 ) distance reduction: -14
# Move: 1284 | Moving 666 from cluster 775 ( size 3 ) to 151 ( size 2 ) distance reduction: -2
# Move: 1285 | Moving 542 from cluster 360 ( size 8 ) to 356 ( size 3 ) distance reduction: -10
# Move: 1286 | Moving 245 from cluster 59 ( size 3 ) to 47 ( size 11 ) distance reduction: -50
# Move: 1287 | Moving 648 from cluster 356 ( size 4 ) to 360 ( size 7 ) distance reduction: -44
# Move: 1288 | Moving 553 from cluster 641 ( size 44 ) to 642 ( size 2 ) distance reduction: -62
# Move: 1289 | Moving 138 from cluster 360 ( size 8 ) to 356 ( size 3 ) distance reduction: -26
# --- 10 / 20 ---
# Move: 1290 | Moving 744 from cluster 187 ( size 3 ) to 273 ( size 7 ) distance reduction: -32
# Move: 1291 | Moving 245 from cluster 47 ( size 12 ) to 59 ( size 2 ) distance reduction: -22
# Move: 1292 | Moving 187 from cluster 775 ( size 2 ) to 151 ( size 3 ) distance reduction: -22
# Move: 1293 | Moving 648 from cluster 360 ( size 7 ) to 356 ( size 4 ) distance reduction: -36
# Move: 1294 | Moving 604 from cluster 356 ( size 5 ) to 113 ( size 8 ) distance reduction: -52
# Move: 1295 | Moving 542 from cluster 356 ( size 4 ) to 360 ( size 6 ) distance reduction: -34
# Move: 1296 | Moving 666 from cluster 151 ( size 4 ) to 775 ( size 1 ) distance reduction: -54
# Move: 1297 | Moving 989 from cluster 360 ( size 7 ) to 356 ( size 3 ) distance reduction: -52
# Move: 1298 | Moving 772 from cluster 360 ( size 6 ) to 356 ( size 4 ) distance reduction: -22
# Move: 1299 | Moving 406 from cluster 360 ( size 5 ) to 356 ( size 5 ) distance reduction: -58
# Move: 1300 | Moving 424 from cluster 118 ( size 10 ) to 59 ( size 3 ) distance reduction: -64
# Move: 1301 | Moving 94 from cluster 98 ( size 41 ) to 187 ( size 2 ) distance reduction: -68
# Move: 1302 | Moving 894 from cluster 151 ( size 3 ) to 775 ( size 2 ) distance reduction: -40
# Move: 1303 | Moving 553 from cluster 642 ( size 3 ) to 641 ( size 43 ) distance reduction: -10
# Move: 1304 | Moving 138 from cluster 356 ( size 6 ) to 360 ( size 4 ) distance reduction: -14
# Move: 1305 | Moving 474 from cluster 775 ( size 3 ) to 7 ( size 20 ) distance reduction: -20
# Move: 1306 | Moving 920 from cluster 360 ( size 5 ) to 356 ( size 5 ) distance reduction: -58
# --- 11 / 20 ---
# Move: 1307 | Moving 159 from cluster 151 ( size 2 ) to 775 ( size 2 ) distance reduction: -18
# Move: 1308 | Moving 910 from cluster 360 ( size 4 ) to 356 ( size 6 ) distance reduction: -68
# Move: 1309 | Moving 406 from cluster 356 ( size 7 ) to 360 ( size 3 ) distance reduction: -18
# Move: 1310 | Moving 604 from cluster 113 ( size 9 ) to 356 ( size 6 ) distance reduction: -20
# Move: 1311 | Moving 187 from cluster 151 ( size 1 ) to 775 ( size 3 ) distance reduction: -12
# Move: 1312 | Moving 744 from cluster 273 ( size 8 ) to 479 ( size 2 ) distance reduction: -32
# Move: 1313 | Moving 138 from cluster 360 ( size 4 ) to 356 ( size 7 ) distance reduction: -54
# Move: 1314 | Moving 920 from cluster 356 ( size 8 ) to 360 ( size 3 ) distance reduction: -4
# Move: 1315 | Moving 788 from cluster 187 ( size 3 ) to 479 ( size 3 ) distance reduction: -44
# Move: 1316 | Moving 560 from cluster 360 ( size 4 ) to 356 ( size 7 ) distance reduction: -16
# Move: 1317 | Moving 542 from cluster 360 ( size 3 ) to 356 ( size 8 ) distance reduction: -50
# Move: 1318 | Moving 553 from cluster 641 ( size 44 ) to 642 ( size 2 ) distance reduction: -62
# Move: 1319 | Moving 982 from cluster 116 ( size 2 ) to 118 ( size 9 ) distance reduction: -18
# Move: 1320 | Moving 245 from cluster 59 ( size 4 ) to 47 ( size 11 ) distance reduction: -68
# Move: 1321 | Moving 772 from cluster 356 ( size 9 ) to 360 ( size 2 ) distance reduction: -40
# Move: 1322 | Moving 474 from cluster 7 ( size 21 ) to 775 ( size 4 ) distance reduction: -22
# Move: 1323 | Moving 648 from cluster 356 ( size 8 ) to 360 ( size 3 ) distance reduction: -4
# --- 12 / 20 ---
# Move: 1324 | Moving 648 from cluster 360 ( size 4 ) to 356 ( size 7 ) distance reduction: -68
# Move: 1325 | Moving 406 from cluster 360 ( size 3 ) to 356 ( size 8 ) distance reduction: -52
# Move: 1326 | Moving 553 from cluster 642 ( size 3 ) to 641 ( size 43 ) distance reduction: -10
# Move: 1327 | Moving 788 from cluster 479 ( size 4 ) to 187 ( size 2 ) distance reduction: -28
# Move: 1328 | Moving 474 from cluster 775 ( size 5 ) to 7 ( size 20 ) distance reduction: -50
# Move: 1329 | Moving 772 from cluster 360 ( size 2 ) to 356 ( size 9 ) distance reduction: -32
# Move: 1330 | Moving 982 from cluster 118 ( size 10 ) to 116 ( size 1 ) distance reduction: -54
# Move: 1331 | Moving 245 from cluster 47 ( size 12 ) to 360 ( size 1 ) distance reduction: -30
# Move: 1332 | Moving 604 from cluster 356 ( size 10 ) to 113 ( size 8 ) distance reduction: -68
# Move: 1333 | Moving 744 from cluster 479 ( size 3 ) to 273 ( size 7 ) distance reduction: -40
# Move: 1334 | Moving 94 from cluster 187 ( size 3 ) to 98 ( size 40 ) distance reduction: -4
# Move: 1335 | Moving 920 from cluster 360 ( size 2 ) to 356 ( size 9 ) distance reduction: -108
# --- 13 / 20 ---
# Move: 1336 | Moving 245 from cluster 360 ( size 1 ) to 47 ( size 11 ) distance reduction: -24
# Move: 1337 | Moving 553 from cluster 641 ( size 44 ) to 642 ( size 2 ) distance reduction: -62
# Move: 1338 | Moving 982 from cluster 116 ( size 2 ) to 118 ( size 9 ) distance reduction: -18
# Move: 1339 | Moving 756 from cluster 273 ( size 8 ) to 187 ( size 2 ) distance reduction: -4
# Move: 1340 | Moving 744 from cluster 273 ( size 7 ) to 187 ( size 3 ) distance reduction: -36
# Move: 1341 | Moving 94 from cluster 98 ( size 41 ) to 187 ( size 4 ) distance reduction: -26
# Move: 1342 | Moving 474 from cluster 7 ( size 21 ) to 479 ( size 2 ) distance reduction: -36
# Move: 1343 | Moving 666 from cluster 775 ( size 4 ) to 479 ( size 3 ) distance reduction: -10
# --- 14 / 20 ---
# Move: 1344 | Moving 474 from cluster 479 ( size 4 ) to 7 ( size 20 ) distance reduction: -40
# Move: 1345 | Moving 666 from cluster 479 ( size 3 ) to 775 ( size 3 ) distance reduction: -58
# Move: 1346 | Moving 553 from cluster 642 ( size 3 ) to 641 ( size 43 ) distance reduction: -10
# Move: 1347 | Moving 744 from cluster 187 ( size 5 ) to 273 ( size 6 ) distance reduction: -58
# Move: 1348 | Moving 982 from cluster 118 ( size 10 ) to 116 ( size 1 ) distance reduction: -54
# Move: 1349 | Moving 94 from cluster 187 ( size 4 ) to 98 ( size 40 ) distance reduction: -24
# Move: 1350 | Moving 245 from cluster 47 ( size 12 ) to 59 ( size 3 ) distance reduction: -4
# Move: 1351 | Moving 756 from cluster 187 ( size 3 ) to 273 ( size 7 ) distance reduction: -68
# --- 15 / 20 ---
# Move: 1352 | Moving 245 from cluster 59 ( size 4 ) to 47 ( size 11 ) distance reduction: -68
# Move: 1353 | Moving 756 from cluster 273 ( size 8 ) to 187 ( size 2 ) distance reduction: -4
# Move: 1354 | Moving 474 from cluster 7 ( size 21 ) to 479 ( size 2 ) distance reduction: -36
# Move: 1355 | Moving 744 from cluster 273 ( size 7 ) to 187 ( size 3 ) distance reduction: -36
# Move: 1356 | Moving 666 from cluster 775 ( size 4 ) to 479 ( size 3 ) distance reduction: -10
# Move: 1357 | Moving 187 from cluster 775 ( size 3 ) to 479 ( size 4 ) distance reduction: -16
# Move: 1358 | Moving 817 from cluster 479 ( size 5 ) to 273 ( size 6 ) distance reduction: -4
# Move: 1359 | Moving 982 from cluster 116 ( size 2 ) to 118 ( size 9 ) distance reduction: -18
# Move: 1360 | Moving 553 from cluster 641 ( size 44 ) to 642 ( size 2 ) distance reduction: -62
# Move: 1361 | Moving 94 from cluster 98 ( size 41 ) to 187 ( size 4 ) distance reduction: -26
# --- 16 / 20 ---
# Move: 1362 | Moving 756 from cluster 187 ( size 5 ) to 273 ( size 7 ) distance reduction: -76
# Move: 1363 | Moving 666 from cluster 479 ( size 4 ) to 775 ( size 2 ) distance reduction: -22
# Move: 1364 | Moving 982 from cluster 118 ( size 10 ) to 116 ( size 1 ) distance reduction: -54
# Move: 1365 | Moving 245 from cluster 47 ( size 12 ) to 59 ( size 3 ) distance reduction: -4
# Move: 1366 | Moving 187 from cluster 479 ( size 3 ) to 775 ( size 3 ) distance reduction: -44
# Move: 1367 | Moving 94 from cluster 187 ( size 4 ) to 98 ( size 40 ) distance reduction: -26
# Move: 1368 | Moving 744 from cluster 187 ( size 3 ) to 479 ( size 2 ) distance reduction: -28
# Move: 1369 | Moving 553 from cluster 642 ( size 3 ) to 641 ( size 43 ) distance reduction: -10
# Move: 1370 | Moving 894 from cluster 775 ( size 4 ) to 479 ( size 3 ) distance reduction: -40
# Move: 1371 | Moving 474 from cluster 479 ( size 4 ) to 775 ( size 3 ) distance reduction: -54
# Move: 1372 | Moving 817 from cluster 273 ( size 8 ) to 479 ( size 3 ) distance reduction: -110
# --- 17 / 20 ---
# Move: 1373 | Moving 982 from cluster 116 ( size 2 ) to 118 ( size 9 ) distance reduction: -18
# Move: 1374 | Moving 788 from cluster 187 ( size 2 ) to 479 ( size 4 ) distance reduction: -8
# Move: 1375 | Moving 245 from cluster 59 ( size 4 ) to 47 ( size 11 ) distance reduction: -68
# Move: 1376 | Moving 894 from cluster 479 ( size 5 ) to 775 ( size 4 ) distance reduction: -50
# Move: 1377 | Moving 474 from cluster 775 ( size 5 ) to 7 ( size 20 ) distance reduction: -50
# Move: 1378 | Moving 744 from cluster 479 ( size 4 ) to 273 ( size 7 ) distance reduction: -38
# Move: 1379 | Moving 553 from cluster 641 ( size 44 ) to 642 ( size 2 ) distance reduction: -62
# Move: 1380 | Moving 94 from cluster 98 ( size 41 ) to 479 ( size 3 ) distance reduction: -44
# --- 18 / 20 ---
# Move: 1381 | Moving 474 from cluster 7 ( size 21 ) to 775 ( size 4 ) distance reduction: -22
# Move: 1382 | Moving 788 from cluster 479 ( size 4 ) to 273 ( size 8 ) distance reduction: -4
# Move: 1383 | Moving 94 from cluster 479 ( size 3 ) to 98 ( size 40 ) distance reduction: -16
# Move: 1384 | Moving 744 from cluster 273 ( size 9 ) to 479 ( size 2 ) distance reduction: -30
# Move: 1385 | Moving 245 from cluster 47 ( size 12 ) to 59 ( size 3 ) distance reduction: -4
# Move: 1386 | Moving 553 from cluster 642 ( size 3 ) to 641 ( size 43 ) distance reduction: -10
# Move: 1387 | Moving 982 from cluster 118 ( size 10 ) to 116 ( size 1 ) distance reduction: -54
# Move: 1388 | Moving 836 from cluster 273 ( size 8 ) to 187 ( size 1 ) distance reduction: -12
# --- 19 / 20 ---
# mu 4 , number of clusters 50

# %%
len(P_list)
# Out:
# 37

# %%
P_star = v1_consensus(P_list)

# %%
print(len(P_star["partition"]))
# Out:
# 38
